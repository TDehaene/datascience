# %% [markdown]
# # Test vision api's

# %%
from IPython.display import Image
url = "https://s-media-cache-ak0.pinimg.com/564x/0c/5c/58/0c5c583b48463fa239faa96cc89f7ae1.jpg"
url = "https://i.pinimg.com/564x/58/de/72/58de72c94dd1eaac2afda7ae23ae1fda.jpg"
Image(url,width=300, height=300)

# %% [markdown]
# ## Test Clarifai api

# %% [markdown]
# #### Setup

# %%
from clarifai.rest import ClarifaiApp


#export CLARIFAI_API_KEY='afaf272b73234677955533e204306c78'   

app = ClarifaiApp(api_key='afaf272b73234677955533e204306c78')
      
# get the general model
model = app.models.get("general-v1.3")
# Out:
# Hey! Clarifai Python Client v%s upgrade available. 2.0.32

# %% [markdown]
# #### Basic example

# %%
from pprint import pprint as pprint

    
# predict with the model
test= model.predict_by_url(url=url)

values = [(value["name"],value["value"]) for value in test["outputs"][0]["data"]["concepts"]]
pprint(values)
# Out:
# [('food', 0.9947231),
#  ('no person', 0.9853009),
#  ('pan', 0.9836534),
#  ('cooking', 0.97628164),
#  ('frying pan', 0.97547036),
#  ('meal', 0.9651722),
#  ('meat', 0.9623277),
#  ('lunch', 0.93686223),
#  ('rustic', 0.929836),
#  ('closeup', 0.9260023),
#  ('sausage', 0.92322826),
#  ('hot', 0.922091),
#  ('dinner', 0.91745996),
#  ('vegetable', 0.91350913),
#  ('dish', 0.91308516),
#  ('delicious', 0.9099287),
#  ('pork', 0.90354717),
#  ('kitchenware', 0.8990144),
#  ('cuisine', 0.8914794),
#  ('cookware', 0.88376874)]

# %% [markdown]
# ## Test Google Vision API

# %%
import io
import os

# Imports the Google Cloud client library
from google.cloud import vision
from google.cloud.vision import types


# Instantiates a client
client = vision.ImageAnnotatorClient()


# Loads the image into memory
with io.open(file_name, 'rb') as image_file:
    content = image_file.read()

image = types.Image(content=content)

# Performs label detection on the image file
response = client.label_detection(image=image)
labels = response.label_annotations

print('Labels:')
for label in labels:
    print(label.description)

# %% [markdown]
# ## Test Microsoft Cognitive AI
