# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.870208
# Nearest to about: whomever, printing, fredericksburg, cutler, eamon, eroded, unknowns, blythe,
# Nearest to have: spearheaded, anz, hetfield, ceos, disorders, sunderland, quarrels, uncovering,
# Nearest to has: interferes, barra, kobayashi, filipinos, vieux, lafayette, unsaturated, minotaurs,
# Nearest to had: prize, sayings, mckeon, incomplete, wayward, rodr, eiji, jonah,
# Nearest to four: jehoram, lubrication, bessel, emiliano, arecibo, sociobiology, gibbs, horizon,
# Nearest to was: auc, pluperfect, monaco, cop, lick, gentler, miscegenation, ouaddai,
# Nearest to however: mandaeans, vitrification, scriptorium, sommerfeld, dorms, illusory, bos, aluminum,
# Nearest to for: andrey, virtuosity, sacking, b, exclave, lenders, simon, axillary,
# Nearest to in: bio, blvd, gunpoint, sprays, engravers, certify, corundum, basing,
# Nearest to five: lymphocyte, abiding, quiz, talons, aide, orang, vladislav, regretted,
# Nearest to nine: tiling, moran, vegetal, andres, sided, xcd, shadow, supercharger,
# Nearest to which: claudel, beautifully, gerhard, wesley, micrometer, heterotic, kristina, tower,
# Nearest to who: dol, colossal, totals, mussolini, avenger, slim, overzealous, haemophilia,
# Nearest to used: secondarily, trent, national, topol, navigation, seoul, wear, conspired,
# Nearest to an: cns, wednesday, fearing, underdeveloped, working, spiced, nugget, colombian,
# Nearest to these: ornamentation, vestiges, kapoor, dakuten, cpi, frites, mushrooms, abbot,
# Average loss at step 2000: 4.373510
# Average loss at step 4000: 3.865220
# Average loss at step 6000: 3.787913
# Average loss at step 8000: 3.687096
# Average loss at step 10000: 3.618214
# Nearest to about: printing, fredericksburg, eucharistic, perry, designate, margins, senegal, gore,
# Nearest to have: had, has, be, were, are, injunctions, bandy, take,
# Nearest to has: had, was, have, interferes, is, takes, scalloped, causes,
# Nearest to had: has, have, was, were, been, metre, could, confining,
# Nearest to four: six, three, five, seven, eight, two, nine, zero,
# Nearest to was: is, has, were, had, by, monte, be, wikibook,
# Nearest to however: dorms, paddock, sheba, classifies, if, illusory, sommerfeld, but,
# Nearest to for: of, garbo, punishable, hey, freebase, in, culprit, jock,
# Nearest to in: of, on, at, with, between, from, expedition, aborigines,
# Nearest to five: six, four, three, eight, nine, seven, zero, two,
# Nearest to nine: eight, seven, five, six, zero, four, three, two,
# Nearest to which: that, this, who, it, and, malacca, he, but,
# Nearest to who: he, they, which, nashville, it, veda, dol, also,
# Nearest to used: seoul, considered, trent, regarded, known, referred, secondarily, obtainable,
# Nearest to an: the, wednesday, biographer, stephen, multithreading, darius, underdeveloped, reservists,
# Nearest to these: ornamentation, carboxyl, vestiges, frites, flows, setback, orient, op,
# Average loss at step 12000: 3.606569
# Average loss at step 14000: 3.572883
# Average loss at step 16000: 3.416082
# Average loss at step 18000: 3.457450
# Average loss at step 20000: 3.545293
# Nearest to about: perry, printing, senegal, moderates, eucharistic, beautifully, margins, fredericksburg,
# Nearest to have: had, has, be, were, are, take, prevent, mise,
# Nearest to has: had, was, have, is, interferes, takes, kuznetsov, does,
# Nearest to had: has, have, was, were, confining, been, could, when,
# Nearest to four: six, five, eight, two, three, seven, nine, one,
# Nearest to was: is, has, were, had, been, became, be, does,
# Nearest to however: but, if, paddock, sheba, dorms, classifies, operettas, though,
# Nearest to for: and, by, of, against, garbo, to, in, formants,
# Nearest to in: at, on, between, from, during, with, corundum, among,
# Nearest to five: seven, six, four, eight, three, two, zero, nine,
# Nearest to nine: eight, seven, six, four, five, zero, three, two,
# Nearest to which: this, that, who, but, it, also, there, these,
# Nearest to who: he, which, they, also, she, there, veda, that,
# Nearest to used: considered, regarded, seoul, known, referred, trent, derived, obtainable,
# Nearest to an: the, wednesday, gravy, polo, internal, selector, unaffected, novella,
# Nearest to these: many, some, which, carboxyl, those, flows, several, reset,
# Average loss at step 22000: 3.495784
# Average loss at step 24000: 3.490253
# Average loss at step 26000: 3.483457
# Average loss at step 28000: 3.481186
# Average loss at step 30000: 3.504329
# Nearest to about: moderates, printing, perry, scoreless, magnificent, dearth, upholding, senegal,
# Nearest to have: had, has, are, were, include, mithra, ve, be,
# Nearest to has: had, have, is, was, interferes, takes, pigot, wikibook,
# Nearest to had: have, has, was, were, confining, having, veyron, is,
# Nearest to four: six, eight, five, three, seven, nine, two, zero,
# Nearest to was: is, had, has, were, became, been, when, monte,
# Nearest to however: but, though, operettas, when, if, while, and, paddock,
# Nearest to for: with, on, to, when, after, by, garbo, against,
# Nearest to in: during, at, of, on, and, throughout, with, under,
# Nearest to five: four, eight, seven, three, six, nine, zero, two,
# Nearest to nine: eight, seven, six, four, five, three, zero, two,
# Nearest to which: this, that, it, also, but, what, who, there,
# Nearest to who: he, they, she, which, there, it, also, and,
# Nearest to used: known, considered, referred, regarded, found, available, seoul, retake,
# Nearest to an: wednesday, biographer, gravy, impunity, reservists, underdeveloped, infighting, polo,
# Nearest to these: some, many, they, those, several, such, all, their,
# Average loss at step 32000: 3.503662
# Average loss at step 34000: 3.499641
# Average loss at step 36000: 3.457031
# Average loss at step 38000: 3.304853
# Average loss at step 40000: 3.427806
# Nearest to about: menelik, senegal, dearth, moderates, antrim, maskhadov, factored, printing,
# Nearest to have: had, has, were, be, are, ve, include, mise,
# Nearest to has: had, have, was, is, underwent, kuznetsov, reached, interferes,
# Nearest to had: has, have, was, confining, were, having, kanpur, veyron,
# Nearest to four: six, eight, three, seven, five, nine, two, one,
# Nearest to was: is, became, were, has, had, been, be, when,
# Nearest to however: but, that, though, operettas, while, relied, and, although,
# Nearest to for: in, of, after, when, and, if, mourner, to,
# Nearest to in: of, during, for, on, at, from, corundum, and,
# Nearest to five: seven, six, three, four, eight, zero, nine, two,
# Nearest to nine: eight, seven, six, four, five, zero, three, deaths,
# Nearest to which: that, this, also, who, there, what, it, but,
# Nearest to who: he, which, she, they, often, deducted, hyperplasia, also,
# Nearest to used: regarded, known, considered, referred, found, available, linguist, seoul,
# Nearest to an: wednesday, novella, polo, biographer, colombian, modified, multiplies, rko,
# Nearest to these: some, many, several, those, they, both, all, there,
# Average loss at step 42000: 3.436453
# Average loss at step 44000: 3.451410
# Average loss at step 46000: 3.449913
# Average loss at step 48000: 3.349251
# Average loss at step 50000: 3.383760
# Nearest to about: antrim, menelik, dearth, defector, moderates, pipelining, maskhadov, energetic,
# Nearest to have: had, has, were, are, be, refer, include, ve,
# Nearest to has: had, have, was, is, underwent, since, hairstyle, does,
# Nearest to had: has, have, was, were, having, confining, limericks, since,
# Nearest to four: five, six, three, seven, eight, nine, two, zero,
# Nearest to was: is, were, has, became, had, be, been, tents,
# Nearest to however: but, although, though, while, that, when, if, where,
# Nearest to for: garbo, reconstructionist, plebeians, discworld, collectively, after, hey, allowing,
# Nearest to in: within, throughout, during, since, between, until, on, sumo,
# Nearest to five: four, six, seven, three, eight, two, zero, nine,
# Nearest to nine: eight, seven, six, four, three, five, zero, two,
# Nearest to which: that, this, also, who, what, often, there, it,
# Nearest to who: he, which, she, they, often, also, usually, have,
# Nearest to used: known, regarded, referred, considered, available, found, written, given,
# Nearest to an: wednesday, the, modified, novella, another, biographer, multiplies, leq,
# Nearest to these: some, many, several, both, those, such, they, various,
# Average loss at step 52000: 3.434837
# Average loss at step 54000: 3.426659
# Average loss at step 56000: 3.437937
# Average loss at step 58000: 3.392904
# Average loss at step 60000: 3.394433
# Nearest to about: moderates, dearth, lees, antrim, maskhadov, regarding, x, menelik,
# Nearest to have: had, has, are, were, ve, include, be, contain,
# Nearest to has: had, have, was, is, underwent, makes, interferes, having,
# Nearest to had: has, have, was, were, having, confining, been, yet,
# Nearest to four: five, six, eight, three, seven, two, nine, zero,
# Nearest to was: is, became, had, has, were, disintegrated, be, does,
# Nearest to however: but, though, although, that, when, while, if, which,
# Nearest to for: of, garbo, when, reconstructionist, including, if, after, hey,
# Nearest to in: within, during, throughout, on, until, between, at, among,
# Nearest to five: four, six, three, eight, seven, nine, zero, two,
# Nearest to nine: eight, seven, six, five, four, zero, three, one,
# Nearest to which: that, this, what, these, it, who, also, however,
# Nearest to who: he, which, she, they, that, also, molino, usually,
# Nearest to used: known, considered, regarded, referred, found, available, written, designed,
# Nearest to an: wednesday, leq, biographer, fcc, polo, modified, another, colombian,
# Nearest to these: some, many, several, those, both, they, which, such,
# Average loss at step 62000: 3.243419
# Average loss at step 64000: 3.254790
# Average loss at step 66000: 3.402543
# Average loss at step 68000: 3.389947
# Average loss at step 70000: 3.360855
# Nearest to about: dearth, moderates, regarding, maskhadov, menelik, lees, blooms, trudeau,
# Nearest to have: had, has, were, are, be, include, contain, produce,
# Nearest to has: had, have, is, was, since, kuznetsov, clitoral, makes,
# Nearest to had: have, has, were, was, having, limericks, confining, been,
# Nearest to four: six, five, seven, eight, three, nine, two, zero,
# Nearest to was: is, were, had, been, has, became, does, when,
# Nearest to however: but, though, although, where, that, when, while, if,
# Nearest to for: garbo, to, in, culprit, if, after, of, and,
# Nearest to in: within, during, on, throughout, from, until, for, through,
# Nearest to five: six, four, three, eight, seven, zero, nine, two,
# Nearest to nine: eight, six, seven, four, five, zero, three, deaths,
# Nearest to which: that, this, what, also, but, essentially, however, and,
# Nearest to who: he, hyperplasia, they, never, she, usually, which, deducted,
# Nearest to used: known, regarded, considered, referred, available, found, cited, written,
# Nearest to an: wednesday, modified, leq, another, brake, bujold, gravy, rko,
# Nearest to these: some, many, such, those, several, various, the, are,
# Average loss at step 72000: 3.379999
# Average loss at step 74000: 3.349830
# Average loss at step 76000: 3.320655
# Average loss at step 78000: 3.354845
# Average loss at step 80000: 3.376882
# Nearest to about: menelik, over, lees, shortwave, approximately, regarding, moderates, invoking,
# Nearest to have: had, has, are, be, were, having, include, contain,
# Nearest to has: had, have, is, was, since, interferes, includes, kuznetsov,
# Nearest to had: has, have, were, was, having, confining, took, came,
# Nearest to four: six, five, seven, eight, three, nine, two, zero,
# Nearest to was: is, became, has, had, were, although, been, be,
# Nearest to however: but, although, though, that, where, when, since, khalifa,
# Nearest to for: garbo, reconstructionist, wider, if, culprit, refueling, when, customary,
# Nearest to in: during, within, on, until, since, at, enactments, of,
# Nearest to five: six, four, seven, eight, three, nine, zero, two,
# Nearest to nine: eight, seven, six, four, five, three, zero, deaths,
# Nearest to which: this, that, also, usually, what, but, where, these,
# Nearest to who: he, she, never, they, usually, which, actually, often,
# Nearest to used: known, regarded, referred, available, found, considered, given, constructed,
# Nearest to an: wednesday, biographer, polo, personages, infighting, gravy, novella, bujold,
# Nearest to these: several, both, those, many, some, such, various, multiple,
# Average loss at step 82000: 3.405291
# Average loss at step 84000: 3.403986
# Average loss at step 86000: 3.393115
# Average loss at step 88000: 3.354015
# Average loss at step 90000: 3.364250
# Nearest to about: menelik, lees, regarding, westport, defector, invoking, over, peppers,
# Nearest to have: had, has, are, were, be, include, having, contain,
# Nearest to has: had, have, is, was, towers, having, makes, since,
# Nearest to had: have, has, was, were, having, kanpur, confining, came,
# Nearest to four: five, seven, eight, six, three, nine, two, zero,
# Nearest to was: is, became, had, were, has, be, been, becomes,
# Nearest to however: but, although, though, that, since, where, when, regarding,
# Nearest to for: garbo, of, without, against, when, if, reconstructionist, after,
# Nearest to in: within, during, with, throughout, at, ae, of, under,
# Nearest to five: four, eight, seven, six, three, nine, two, zero,
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to which: that, this, usually, also, what, these, but, essentially,
# Nearest to who: he, she, often, they, ruthenian, which, never, and,
# Nearest to used: known, regarded, referred, found, considered, available, cited, constructed,
# Nearest to an: wednesday, another, biographer, polo, comedian, novella, cossacks, rko,
# Nearest to these: many, several, some, both, those, such, various, multiple,
# Average loss at step 92000: 3.395325
# Average loss at step 94000: 3.250829
# Average loss at step 96000: 3.358399
# Average loss at step 98000: 3.240727
# Average loss at step 100000: 3.361827
# Nearest to about: around, menelik, lees, invoking, regarding, ineffective, circumnavigate, trudeau,
# Nearest to have: had, has, were, having, include, are, be, require,
# Nearest to has: had, have, is, was, since, kuznetsov, believes, counterexamples,
# Nearest to had: has, have, was, having, were, took, could, would,
# Nearest to four: five, six, seven, eight, three, two, nine, zero,
# Nearest to was: is, became, had, were, has, remained, when, been,
# Nearest to however: but, although, that, though, where, which, when, today,
# Nearest to for: without, if, when, including, garbo, after, culprit, ricimer,
# Nearest to in: during, within, throughout, until, on, from, at, of,
# Nearest to five: six, four, seven, eight, zero, nine, three, two,
# Nearest to nine: eight, seven, six, four, five, three, zero, deaths,
# Nearest to which: that, this, what, usually, these, actually, however, also,
# Nearest to who: he, never, she, actually, which, ruthenian, often, also,
# Nearest to used: regarded, referred, known, available, found, considered, constructed, given,
# Nearest to an: wednesday, another, bujold, rko, polo, newsletters, leq, novella,
# Nearest to these: many, several, some, those, various, all, both, multiple,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
