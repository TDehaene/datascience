# %% [markdown]
# # Titanic: Machine Learning from Disaster

# %% [markdown]
# ## Basic imports

# %%
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

import pandas as pd

# %% [markdown]
# ## Importing and checking data

# %%
df_train = pd.read_csv('train.csv')
print df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## Prepping and splitting the data

# %%
X = df_train[["Pclass","Sex","Fare","Age","SibSp"]]
y = df_train["Survived"]

# %% [markdown]
# ## Encoding categorical values

# %%
X_encoded = pd.get_dummies(X)
print X_encoded.head(10)
# Out:
#    Pclass     Fare   Age  SibSp  Sex_female  Sex_male
# 0       3   7.2500  22.0      1           0         1
# 1       1  71.2833  38.0      1           1         0
# 2       3   7.9250  26.0      0           1         0
# 3       1  53.1000  35.0      1           1         0
# 4       3   8.0500  35.0      0           0         1
# 5       3   8.4583   NaN      0           0         1
# 6       1  51.8625  54.0      0           0         1
# 7       3  21.0750   2.0      3           0         1
# 8       3  11.1333  27.0      0           1         0
# 9       2  30.0708  14.0      1           1         0

# %% [markdown]
# ## Filling in missing values

# %%
from sklearn.preprocessing import Imputer
imp = Imputer(missing_values='NaN', strategy='mean',axis=0)
imp.fit(X_encoded)
X_imputed = imp.transform(X_encoded)
print X_imputed[:,2]
# Out:
# [ 22.          38.          26.          35.          35.          29.69911765
#   54.           2.          27.          14.           4.          58.          20.
#   39.          14.          55.           2.          29.69911765  31.
#   29.69911765  35.          34.          15.          28.           8.          38.
#   29.69911765  19.          29.69911765  29.69911765  40.          29.69911765
#   29.69911765  66.          28.          42.          29.69911765  21.          18.
#   14.          40.          27.          29.69911765   3.          19.
#   29.69911765  29.69911765  29.69911765  29.69911765  18.           7.          21.
#   49.          29.          65.          29.69911765  21.          28.5
#    5.          11.          22.          38.          45.           4.
#   29.69911765  29.69911765  29.          19.          17.          26.          32.
#   16.          21.          26.          32.          25.          29.69911765
#   29.69911765   0.83        30.          22.          29.          29.69911765
#   28.          17.          33.          16.          29.69911765  23.          24.
#   29.          20.          46.          26.          59.          29.69911765
#   71.          23.          34.          34.          28.          29.69911765
#   21.          33.          37.          28.          21.          29.69911765
#   38.          29.69911765  47.          14.5         22.          20.          17.
#   21.          70.5         29.          24.           2.          21.
#   29.69911765  32.5         32.5         54.          12.          29.69911765
#   24.          29.69911765  45.          33.          20.          47.          29.
#   25.          23.          19.          37.          16.          24.
#   29.69911765  22.          24.          19.          18.          19.          27.
#    9.          36.5         42.          51.          22.          55.5
#   40.5         29.69911765  51.          16.          30.          29.69911765
#   29.69911765  44.          40.          26.          17.           1.           9.
#   29.69911765  45.          29.69911765  28.          61.           4.           1.
#   21.          56.          18.          29.69911765  50.          30.          36.
#   29.69911765  29.69911765   9.           1.           4.          29.69911765
#   29.69911765  45.          40.          36.          32.          19.          19.
#    3.          44.          58.          29.69911765  42.          29.69911765
#   24.          28.          29.69911765  34.          45.5         18.           2.
#   32.          26.          16.          40.          24.          35.          22.
#   30.          29.69911765  31.          27.          42.          32.          30.
#   16.          27.          51.          29.69911765  38.          22.          19.
#   20.5         18.          29.69911765  35.          29.          59.           5.
#   24.          29.69911765  44.           8.          19.          33.
#   29.69911765  29.69911765  29.          22.          30.          44.          25.
#   24.          37.          54.          29.69911765  29.          62.          30.
#   41.          29.          29.69911765  30.          35.          50.
#   29.69911765   3.          52.          40.          29.69911765  36.          16.
#   25.          58.          35.          29.69911765  25.          41.          37.
#   29.69911765  63.          45.          29.69911765   7.          35.          65.
#   28.          16.          19.          29.69911765  33.          30.          22.
#   42.          22.          26.          19.          36.          24.          24.
#   29.69911765  23.5          2.          29.69911765  50.          29.69911765
#   29.69911765  19.          29.69911765  29.69911765   0.92        29.69911765
#   17.          30.          30.          24.          18.          26.          28.
#   43.          26.          24.          54.          31.          40.          22.
#   27.          30.          22.          29.69911765  36.          61.          36.
#   31.          16.          29.69911765  45.5         38.          16.
#   29.69911765  29.69911765  29.          41.          45.          45.           2.
#   24.          28.          25.          36.          24.          40.
#   29.69911765   3.          42.          23.          29.69911765  15.          25.
#   29.69911765  28.          22.          38.          29.69911765
#   29.69911765  40.          29.          45.          35.          29.69911765
#   30.          60.          29.69911765  29.69911765  24.          25.          18.
#   19.          22.           3.          29.69911765  22.          27.          20.
#   19.          42.           1.          32.          35.          29.69911765
#   18.           1.          36.          29.69911765  17.          36.          21.
#   28.          23.          24.          22.          31.          46.          23.
#   28.          39.          26.          21.          28.          20.          34.
#   51.           3.          21.          29.69911765  29.69911765
#   29.69911765  33.          29.69911765  44.          29.69911765  34.          18.
#   30.          10.          29.69911765  21.          29.          28.          18.
#   29.69911765  28.          19.          29.69911765  32.          28.
#   29.69911765  42.          17.          50.          14.          21.          24.
#   64.          31.          45.          20.          25.          28.
#   29.69911765   4.          13.          34.           5.          52.          36.
#   29.69911765  30.          49.          29.69911765  29.          65.
#   29.69911765  50.          29.69911765  48.          34.          47.          48.
#   29.69911765  38.          29.69911765  56.          29.69911765   0.75
#   29.69911765  38.          33.          23.          22.          29.69911765
#   34.          29.          22.           2.           9.          29.69911765
#   50.          63.          25.          29.69911765  35.          58.          30.
#    9.          29.69911765  21.          55.          71.          21.
#   29.69911765  54.          29.69911765  25.          24.          17.          21.
#   29.69911765  37.          16.          18.          33.          29.69911765
#   28.          26.          29.          29.69911765  36.          54.          24.
#   47.          34.          29.69911765  36.          32.          30.          22.
#   29.69911765  44.          29.69911765  40.5         50.          29.69911765
#   39.          23.           2.          29.69911765  17.          29.69911765
#   30.           7.          45.          30.          29.69911765  22.          36.
#    9.          11.          32.          50.          64.          19.
#   29.69911765  33.           8.          17.          27.          29.69911765
#   22.          22.          62.          48.          29.69911765  39.          36.
#   29.69911765  40.          28.          29.69911765  29.69911765  24.          19.
#   29.          29.69911765  32.          62.          53.          36.
#   29.69911765  16.          19.          34.          39.          29.69911765
#   32.          25.          39.          54.          36.          29.69911765
#   18.          47.          60.          22.          29.69911765  35.          52.
#   47.          29.69911765  37.          36.          29.69911765  49.
#   29.69911765  49.          24.          29.69911765  29.69911765  44.          35.
#   36.          30.          27.          22.          40.          39.
#   29.69911765  29.69911765  29.69911765  35.          24.          34.          26.
#    4.          26.          27.          42.          20.          21.          21.
#   61.          57.          21.          26.          29.69911765  80.          51.
#   32.          29.69911765   9.          28.          32.          31.          41.
#   29.69911765  20.          24.           2.          29.69911765   0.75
#   48.          19.          56.          29.69911765  23.          29.69911765
#   18.          21.          29.69911765  18.          24.          29.69911765
#   32.          23.          58.          50.          40.          47.          36.
#   20.          32.          25.          29.69911765  43.          29.69911765
#   40.          31.          70.          31.          29.69911765  18.
#   24.5         18.          43.          36.          29.69911765  27.          20.
#   14.          60.          25.          14.          19.          18.          15.
#   31.           4.          29.69911765  25.          60.          52.          44.
#   29.69911765  49.          42.          18.          35.          18.          25.
#   26.          39.          45.          42.          22.          29.69911765
#   24.          29.69911765  48.          29.          52.          19.          38.
#   27.          29.69911765  33.           6.          17.          34.          50.
#   27.          20.          30.          29.69911765  25.          25.          29.
#   11.          29.69911765  23.          23.          28.5         48.          35.
#   29.69911765  29.69911765  29.69911765  36.          21.          24.          31.
#   70.          16.          30.          19.          31.           4.           6.
#   33.          23.          48.           0.67        28.          18.          34.
#   33.          29.69911765  41.          20.          36.          16.          51.
#   29.69911765  30.5         29.69911765  32.          24.          48.          57.
#   29.69911765  54.          18.          29.69911765   5.          29.69911765
#   43.          13.          17.          29.          29.69911765  25.          25.
#   18.           8.           1.          46.          29.69911765  16.
#   29.69911765  29.69911765  25.          39.          49.          31.          30.
#   30.          34.          31.          11.           0.42        27.          31.
#   39.          18.          39.          33.          26.          39.          35.
#    6.          30.5         29.69911765  23.          31.          43.          10.
#   52.          27.          38.          27.           2.          29.69911765
#   29.69911765   1.          29.69911765  62.          15.           0.83
#   29.69911765  23.          18.          39.          21.          29.69911765
#   32.          29.69911765  20.          16.          30.          34.5
#   17.          42.          29.69911765  35.          28.          29.69911765
#    4.          74.           9.          16.          44.          18.          45.
#   51.          24.          29.69911765  41.          21.          48.
#   29.69911765  24.          42.          27.          31.          29.69911765
#    4.          26.          47.          33.          47.          28.          15.
#   20.          19.          29.69911765  56.          25.          33.          22.
#   28.          25.          39.          27.          19.          29.69911765
#   26.          32.        ]

# %% [markdown]
# ## Constructing a basic nb classifier

# %%
X_train,X_test,y_train,y_test = train_test_split(X_imputed,y,random_state = 11, test_size= 0.2)
nb = GaussianNB()
nb.fit(X_train,y_train)
y_predict = nb.predict(X_test)
print 'Basic NB accuracy with two features: ' + str(round(accuracy_score(y_test,y_predict),3) *100) + '%'
# Out:
# Basic NB accuracy with two features: 84.9%

# %% [markdown]
# ## Constructing a basic SVM classifier

# %%
sv = SVC()
sv.fit(X_train,y_train)
y_predict = sv.predict(X_test)
print 'Basic SVM accuracy with two features: ' + str(round(accuracy_score(y_test,y_predict),3) *100) + '%'
# Out:
# Basic SVM accuracy with two features: 80.4%

# %% [markdown]
# ## Constructing a basic DecisionTree classifier

# %%
dt = DecisionTreeClassifier()
dt.fit(X_train,y_train)
y_predict = dt.predict(X_test)
print 'Basic DT accuracy: ' + str(round(accuracy_score(y_test,y_predict),3) *100) + '%'
# Out:
# Basic DT accuracy: 79.3%

# %% [markdown]
# ## Constructing a basic Neural Network

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled=  scaler.transform(X_test)
print X_test_scaled
nn = MLPClassifier(solver='adam', alpha=0.0001,hidden_layer_sizes=(9, 600), random_state=11,max_iter = 10000)
nn.fit(X_train_scaled, y_train) 
y_predict = nn.predict(X_test_scaled)
print 'Basic NN accuracy: ' + str(round(accuracy_score(y_test,y_predict),3) *100) + '%'
# Out:
# [[ 0.8249189  -0.32990743  0.0057571   0.41160985  1.34693328 -1.34693328]
#  [ 0.8249189  -0.47522138 -0.19943268 -0.46846887 -0.74242727  0.74242727]
#  [ 0.8249189  -0.4933761   0.0057571  -0.46846887 -0.74242727  0.74242727]
#  ...,
#  [ 0.8249189  -0.49020117 -0.57953797 -0.46846887 -0.74242727  0.74242727]
#  [-1.55780832 -0.12573522  0.0057571  -0.46846887 -0.74242727  0.74242727]
#  [-1.55780832  1.13503694 -0.35147479  0.41160985 -0.74242727  0.74242727]]
# Basic NN accuracy: 87.2%

# %% [markdown]
# ## Constructing a basic RandomForest classifier

# %%
rf = RandomForestClassifier(bootstrap=True,random_state=1)
rf.fit(X_train,y_train)
y_predict = rf.predict(X_test)
print 'Basic RF accuracy helene: ' + str(round(accuracy_score(y_test,y_predict),3) *100) + '%'
# Out:
# Basic RF accuracy helene: 84.4%

# %% [markdown]
# ## Building on best solution so far: RF and NN

# %% [markdown]
# ### Hyperparameter tuning on RF

# %%
from sklearn.model_selection import GridSearchCV
fulllist =  range(1,20)
unevensList = [x for x in fulllist if x % 2 != 0]
parameters = {'n_estimators':range(2,50),'min_samples_split':range(2,30)}
rf = RandomForestClassifier(bootstrap=True,warm_start=True)
cv = GridSearchCV(rf, parameters,verbose = 1)
cv.fit(X_train,y_train)
y_predict = cv.predict(X_test)
print 'Optimised RF accuracy: ' + str(round(accuracy_score(y_test,y_predict),3) *100) + '%'
# Out:
# Fitting 3 folds for each of 1344 candidates, totalling 4032 fits
# Optimised RF accuracy: 87.2%
# [Parallel(n_jobs=1)]: Done 4032 out of 4032 | elapsed:  5.7min finished

# %% [markdown]
# ### Hyperparameter tuning on Neural network

# %%
from sklearn.model_selection import GridSearchCV

parameters = {'solver':['lbfgs','adam'],'alpha':[0.000001,0.00001,0.0001,0.001,0.01,0.1],'learning_rate':['adaptive','constant'],'warm_start':[True,False]}
nn = MLPClassifier(hidden_layer_sizes=(10, 5), random_state=3,max_iter = 10000)

cv = GridSearchCV(nn, parameters,verbose = 2)
cv.fit(X_train_scaled,y_train)
y_predict = cv.predict(X_test_scaled)

print 'Optimised NN accuracy: ' + str(round(accuracy_score(y_test,y_predict),3) *100) + '%'
# Out:
# Fitting 3 folds for each of 48 candidates, totalling 144 fits
# [CV] warm_start=True, alpha=1e-06, learning_rate=adaptive, solver=lbfgs
# [CV]  warm_start=True, alpha=1e-06, learning_rate=adaptive, solver=lbfgs, total=   1.2s
# [CV] warm_start=True, alpha=1e-06, learning_rate=adaptive, solver=lbfgs
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.2s remaining:    0.0s
# [CV]  warm_start=True, alpha=1e-06, learning_rate=adaptive, solver=lbfgs, total=   0.7s
# [CV] warm_start=True, alpha=1e-06, learning_rate=adaptive, solver=lbfgs
# [CV]  warm_start=True, alpha=1e-06, learning_rate=adaptive, solver=lbfgs, total=   0.5s
# [CV] warm_start=False, alpha=1e-06, learning_rate=adaptive, solver=lbfgs
# [CV]  warm_start=False, alpha=1e-06, learning_rate=adaptive, solver=lbfgs, total=   1.1s
# [CV] warm_start=False, alpha=1e-06, learning_rate=adaptive, solver=lbfgs
# [CV]  warm_start=False, alpha=1e-06, learning_rate=adaptive, solver=lbfgs, total=   0.7s
# [CV] warm_start=False, alpha=1e-06, learning_rate=adaptive, solver=lbfgs
# [CV]  warm_start=False, alpha=1e-06, learning_rate=adaptive, solver=lbfgs, total=   0.5s
# [CV] warm_start=True, alpha=1e-06, learning_rate=adaptive, solver=adam
# [CV]  warm_start=True, alpha=1e-06, learning_rate=adaptive, solver=adam, total=   0.1s
# [CV] warm_start=True, alpha=1e-06, learning_rate=adaptive, solver=adam
# [CV]  warm_start=True, alpha=1e-06, learning_rate=adaptive, solver=adam, total=   0.1s
# [CV] warm_start=True, alpha=1e-06, learning_rate=adaptive, solver=adam
# [CV]  warm_start=True, alpha=1e-06, learning_rate=adaptive, solver=adam, total=   0.1s
# [CV] warm_start=False, alpha=1e-06, learning_rate=adaptive, solver=adam
# [CV]  warm_start=False, alpha=1e-06, learning_rate=adaptive, solver=adam, total=   0.1s
# [CV] warm_start=False, alpha=1e-06, learning_rate=adaptive, solver=adam
# [CV]  warm_start=False, alpha=1e-06, learning_rate=adaptive, solver=adam, total=   0.1s
# [CV] warm_start=False, alpha=1e-06, learning_rate=adaptive, solver=adam
# [CV]  warm_start=False, alpha=1e-06, learning_rate=adaptive, solver=adam, total=   0.1s
# [CV] warm_start=True, alpha=1e-06, learning_rate=constant, solver=lbfgs
# [CV]  warm_start=True, alpha=1e-06, learning_rate=constant, solver=lbfgs, total=   1.2s
# [CV] warm_start=True, alpha=1e-06, learning_rate=constant, solver=lbfgs
# [CV]  warm_start=True, alpha=1e-06, learning_rate=constant, solver=lbfgs, total=   0.7s
# [CV] warm_start=True, alpha=1e-06, learning_rate=constant, solver=lbfgs
# [CV]  warm_start=True, alpha=1e-06, learning_rate=constant, solver=lbfgs, total=   0.5s
# [CV] warm_start=False, alpha=1e-06, learning_rate=constant, solver=lbfgs
# [CV]  warm_start=False, alpha=1e-06, learning_rate=constant, solver=lbfgs, total=   1.1s
# [CV] warm_start=False, alpha=1e-06, learning_rate=constant, solver=lbfgs
# [CV]  warm_start=False, alpha=1e-06, learning_rate=constant, solver=lbfgs, total=   0.7s
# [CV] warm_start=False, alpha=1e-06, learning_rate=constant, solver=lbfgs
# [CV]  warm_start=False, alpha=1e-06, learning_rate=constant, solver=lbfgs, total=   0.5s
# [CV] warm_start=True, alpha=1e-06, learning_rate=constant, solver=adam
# [CV]  warm_start=True, alpha=1e-06, learning_rate=constant, solver=adam, total=   0.1s
# [CV] warm_start=True, alpha=1e-06, learning_rate=constant, solver=adam
# [CV]  warm_start=True, alpha=1e-06, learning_rate=constant, solver=adam, total=   0.2s
# [CV] warm_start=True, alpha=1e-06, learning_rate=constant, solver=adam
# [CV]  warm_start=True, alpha=1e-06, learning_rate=constant, solver=adam, total=   0.1s
# [CV] warm_start=False, alpha=1e-06, learning_rate=constant, solver=adam
# [CV]  warm_start=False, alpha=1e-06, learning_rate=constant, solver=adam, total=   0.1s
# [CV] warm_start=False, alpha=1e-06, learning_rate=constant, solver=adam
# [CV]  warm_start=False, alpha=1e-06, learning_rate=constant, solver=adam, total=   0.1s
# [CV] warm_start=False, alpha=1e-06, learning_rate=constant, solver=adam
# [CV]  warm_start=False, alpha=1e-06, learning_rate=constant, solver=adam, total=   0.1s
# [CV] warm_start=True, alpha=1e-05, learning_rate=adaptive, solver=lbfgs
# [CV]  warm_start=True, alpha=1e-05, learning_rate=adaptive, solver=lbfgs, total=   0.9s
# [CV] warm_start=True, alpha=1e-05, learning_rate=adaptive, solver=lbfgs
# [CV]  warm_start=True, alpha=1e-05, learning_rate=adaptive, solver=lbfgs, total=   0.4s
# [CV] warm_start=True, alpha=1e-05, learning_rate=adaptive, solver=lbfgs
# [CV]  warm_start=True, alpha=1e-05, learning_rate=adaptive, solver=lbfgs, total=   0.7s
# [CV] warm_start=False, alpha=1e-05, learning_rate=adaptive, solver=lbfgs
# [CV]  warm_start=False, alpha=1e-05, learning_rate=adaptive, solver=lbfgs, total=   0.9s
# [CV] warm_start=False, alpha=1e-05, learning_rate=adaptive, solver=lbfgs
# [CV]  warm_start=False, alpha=1e-05, learning_rate=adaptive, solver=lbfgs, total=   0.4s
# [CV] warm_start=False, alpha=1e-05, learning_rate=adaptive, solver=lbfgs
# [CV]  warm_start=False, alpha=1e-05, learning_rate=adaptive, solver=lbfgs, total=   0.7s
# [CV] warm_start=True, alpha=1e-05, learning_rate=adaptive, solver=adam
# [CV]  warm_start=True, alpha=1e-05, learning_rate=adaptive, solver=adam, total=   0.1s
# [CV] warm_start=True, alpha=1e-05, learning_rate=adaptive, solver=adam
# [CV]  warm_start=True, alpha=1e-05, learning_rate=adaptive, solver=adam, total=   0.1s
# [CV] warm_start=True, alpha=1e-05, learning_rate=adaptive, solver=adam
# [CV]  warm_start=True, alpha=1e-05, learning_rate=adaptive, solver=adam, total=   0.1s
# [CV] warm_start=False, alpha=1e-05, learning_rate=adaptive, solver=adam
# [CV]  warm_start=False, alpha=1e-05, learning_rate=adaptive, solver=adam, total=   0.1s
# [CV] warm_start=False, alpha=1e-05, learning_rate=adaptive, solver=adam
# [CV]  warm_start=False, alpha=1e-05, learning_rate=adaptive, solver=adam, total=   0.1s
# [CV] warm_start=False, alpha=1e-05, learning_rate=adaptive, solver=adam
# [CV]  warm_start=False, alpha=1e-05, learning_rate=adaptive, solver=adam, total=   0.1s
# [CV] warm_start=True, alpha=1e-05, learning_rate=constant, solver=lbfgs
# [CV]  warm_start=True, alpha=1e-05, learning_rate=constant, solver=lbfgs, total=   0.9s
# [CV] warm_start=True, alpha=1e-05, learning_rate=constant, solver=lbfgs
# [CV]  warm_start=True, alpha=1e-05, learning_rate=constant, solver=lbfgs, total=   0.4s
# [CV] warm_start=True, alpha=1e-05, learning_rate=constant, solver=lbfgs
# [CV]  warm_start=True, alpha=1e-05, learning_rate=constant, solver=lbfgs, total=   0.7s
# [CV] warm_start=False, alpha=1e-05, learning_rate=constant, solver=lbfgs
# [CV]  warm_start=False, alpha=1e-05, learning_rate=constant, solver=lbfgs, total=   0.9s
# [CV] warm_start=False, alpha=1e-05, learning_rate=constant, solver=lbfgs
# [CV]  warm_start=False, alpha=1e-05, learning_rate=constant, solver=lbfgs, total=   0.4s
# [CV] warm_start=False, alpha=1e-05, learning_rate=constant, solver=lbfgs
# [CV]  warm_start=False, alpha=1e-05, learning_rate=constant, solver=lbfgs, total=   0.7s
# [CV] warm_start=True, alpha=1e-05, learning_rate=constant, solver=adam
# [CV]  warm_start=True, alpha=1e-05, learning_rate=constant, solver=adam, total=   0.1s
# [CV] warm_start=True, alpha=1e-05, learning_rate=constant, solver=adam
# [CV]  warm_start=True, alpha=1e-05, learning_rate=constant, solver=adam, total=   0.1s
# [CV] warm_start=True, alpha=1e-05, learning_rate=constant, solver=adam
# [CV]  warm_start=True, alpha=1e-05, learning_rate=constant, solver=adam, total=   0.1s
# [CV] warm_start=False, alpha=1e-05, learning_rate=constant, solver=adam
# [CV]  warm_start=False, alpha=1e-05, learning_rate=constant, solver=adam, total=   0.1s
# [CV] warm_start=False, alpha=1e-05, learning_rate=constant, solver=adam
# [CV]  warm_start=False, alpha=1e-05, learning_rate=constant, solver=adam, total=   0.1s
# [CV] warm_start=False, alpha=1e-05, learning_rate=constant, solver=adam
# [CV]  warm_start=False, alpha=1e-05, learning_rate=constant, solver=adam, total=   0.1s
# [CV] warm_start=True, alpha=0.0001, learning_rate=adaptive, solver=lbfgs
# [CV]  warm_start=True, alpha=0.0001, learning_rate=adaptive, solver=lbfgs, total=   0.7s
# [CV] warm_start=True, alpha=0.0001, learning_rate=adaptive, solver=lbfgs
# [CV]  warm_start=True, alpha=0.0001, learning_rate=adaptive, solver=lbfgs, total=   0.3s
# [CV] warm_start=True, alpha=0.0001, learning_rate=adaptive, solver=lbfgs
# [CV]  warm_start=True, alpha=0.0001, learning_rate=adaptive, solver=lbfgs, total=   0.2s
# [CV] warm_start=False, alpha=0.0001, learning_rate=adaptive, solver=lbfgs
# [CV]  warm_start=False, alpha=0.0001, learning_rate=adaptive, solver=lbfgs, total=   0.7s
# [CV] warm_start=False, alpha=0.0001, learning_rate=adaptive, solver=lbfgs
# [CV]  warm_start=False, alpha=0.0001, learning_rate=adaptive, solver=lbfgs, total=   0.3s
# [CV] warm_start=False, alpha=0.0001, learning_rate=adaptive, solver=lbfgs
# [CV]  warm_start=False, alpha=0.0001, learning_rate=adaptive, solver=lbfgs, total=   0.2s
# [CV] warm_start=True, alpha=0.0001, learning_rate=adaptive, solver=adam
# [CV]  warm_start=True, alpha=0.0001, learning_rate=adaptive, solver=adam, total=   0.1s
# [CV] warm_start=True, alpha=0.0001, learning_rate=adaptive, solver=adam
# [CV]  warm_start=True, alpha=0.0001, learning_rate=adaptive, solver=adam, total=   0.1s
# [CV] warm_start=True, alpha=0.0001, learning_rate=adaptive, solver=adam
# [CV]  warm_start=True, alpha=0.0001, learning_rate=adaptive, solver=adam, total=   0.1s
# [CV] warm_start=False, alpha=0.0001, learning_rate=adaptive, solver=adam
# [CV]  warm_start=False, alpha=0.0001, learning_rate=adaptive, solver=adam, total=   0.1s
# [CV] warm_start=False, alpha=0.0001, learning_rate=adaptive, solver=adam
# [CV]  warm_start=False, alpha=0.0001, learning_rate=adaptive, solver=adam, total=   0.2s
# [CV] warm_start=False, alpha=0.0001, learning_rate=adaptive, solver=adam
# [CV]  warm_start=False, alpha=0.0001, learning_rate=adaptive, solver=adam, total=   0.1s
# [CV] warm_start=True, alpha=0.0001, learning_rate=constant, solver=lbfgs
# [CV]  warm_start=True, alpha=0.0001, learning_rate=constant, solver=lbfgs, total=   0.7s
# [CV] warm_start=True, alpha=0.0001, learning_rate=constant, solver=lbfgs
# [CV]  warm_start=True, alpha=0.0001, learning_rate=constant, solver=lbfgs, total=   0.3s
# [CV] warm_start=True, alpha=0.0001, learning_rate=constant, solver=lbfgs
# [CV]  warm_start=True, alpha=0.0001, learning_rate=constant, solver=lbfgs, total=   0.2s
# [CV] warm_start=False, alpha=0.0001, learning_rate=constant, solver=lbfgs
# [CV]  warm_start=False, alpha=0.0001, learning_rate=constant, solver=lbfgs, total=   0.7s
# [CV] warm_start=False, alpha=0.0001, learning_rate=constant, solver=lbfgs
# [CV]  warm_start=False, alpha=0.0001, learning_rate=constant, solver=lbfgs, total=   0.3s
# [CV] warm_start=False, alpha=0.0001, learning_rate=constant, solver=lbfgs
# [CV]  warm_start=False, alpha=0.0001, learning_rate=constant, solver=lbfgs, total=   0.2s
# [CV] warm_start=True, alpha=0.0001, learning_rate=constant, solver=adam
# [CV]  warm_start=True, alpha=0.0001, learning_rate=constant, solver=adam, total=   0.1s
# [CV] warm_start=True, alpha=0.0001, learning_rate=constant, solver=adam
# [CV]  warm_start=True, alpha=0.0001, learning_rate=constant, solver=adam, total=   0.2s
# [CV] warm_start=True, alpha=0.0001, learning_rate=constant, solver=adam
# [CV]  warm_start=True, alpha=0.0001, learning_rate=constant, solver=adam, total=   0.1s
# [CV] warm_start=False, alpha=0.0001, learning_rate=constant, solver=adam
# [CV]  warm_start=False, alpha=0.0001, learning_rate=constant, solver=adam, total=   0.1s
# [CV] warm_start=False, alpha=0.0001, learning_rate=constant, solver=adam
# [CV]  warm_start=False, alpha=0.0001, learning_rate=constant, solver=adam, total=   0.1s
# [CV] warm_start=False, alpha=0.0001, learning_rate=constant, solver=adam
# [CV]  warm_start=False, alpha=0.0001, learning_rate=constant, solver=adam, total=   0.1s
# [CV] warm_start=True, alpha=0.001, learning_rate=adaptive, solver=lbfgs
# [CV]  warm_start=True, alpha=0.001, learning_rate=adaptive, solver=lbfgs, total=   0.5s
# [CV] warm_start=True, alpha=0.001, learning_rate=adaptive, solver=lbfgs
# [CV]  warm_start=True, alpha=0.001, learning_rate=adaptive, solver=lbfgs, total=   0.7s
# [CV] warm_start=True, alpha=0.001, learning_rate=adaptive, solver=lbfgs
# [CV]  warm_start=True, alpha=0.001, learning_rate=adaptive, solver=lbfgs, total=   0.8s
# [CV] warm_start=False, alpha=0.001, learning_rate=adaptive, solver=lbfgs
# [CV]  warm_start=False, alpha=0.001, learning_rate=adaptive, solver=lbfgs, total=   0.5s
# [CV] warm_start=False, alpha=0.001, learning_rate=adaptive, solver=lbfgs
# [CV]  warm_start=False, alpha=0.001, learning_rate=adaptive, solver=lbfgs, total=   0.7s
# [CV] warm_start=False, alpha=0.001, learning_rate=adaptive, solver=lbfgs
# [CV]  warm_start=False, alpha=0.001, learning_rate=adaptive, solver=lbfgs, total=   0.8s
# [CV] warm_start=True, alpha=0.001, learning_rate=adaptive, solver=adam
# [CV]  warm_start=True, alpha=0.001, learning_rate=adaptive, solver=adam, total=   0.1s
# [CV] warm_start=True, alpha=0.001, learning_rate=adaptive, solver=adam
# [CV]  warm_start=True, alpha=0.001, learning_rate=adaptive, solver=adam, total=   0.2s
# [CV] warm_start=True, alpha=0.001, learning_rate=adaptive, solver=adam
# [CV]  warm_start=True, alpha=0.001, learning_rate=adaptive, solver=adam, total=   0.1s
# [CV] warm_start=False, alpha=0.001, learning_rate=adaptive, solver=adam
# [CV]  warm_start=False, alpha=0.001, learning_rate=adaptive, solver=adam, total=   0.1s
# [CV] warm_start=False, alpha=0.001, learning_rate=adaptive, solver=adam
# [CV]  warm_start=False, alpha=0.001, learning_rate=adaptive, solver=adam, total=   0.2s
# [CV] warm_start=False, alpha=0.001, learning_rate=adaptive, solver=adam
# [CV]  warm_start=False, alpha=0.001, learning_rate=adaptive, solver=adam, total=   0.1s
# [CV] warm_start=True, alpha=0.001, learning_rate=constant, solver=lbfgs
# [CV]  warm_start=True, alpha=0.001, learning_rate=constant, solver=lbfgs, total=   0.5s
# [CV] warm_start=True, alpha=0.001, learning_rate=constant, solver=lbfgs
# [CV]  warm_start=True, alpha=0.001, learning_rate=constant, solver=lbfgs, total=   0.6s
# [CV] warm_start=True, alpha=0.001, learning_rate=constant, solver=lbfgs
# [CV]  warm_start=True, alpha=0.001, learning_rate=constant, solver=lbfgs, total=   0.7s
# [CV] warm_start=False, alpha=0.001, learning_rate=constant, solver=lbfgs
# [CV]  warm_start=False, alpha=0.001, learning_rate=constant, solver=lbfgs, total=   0.5s
# [CV] warm_start=False, alpha=0.001, learning_rate=constant, solver=lbfgs
# [CV]  warm_start=False, alpha=0.001, learning_rate=constant, solver=lbfgs, total=   0.6s
# [CV] warm_start=False, alpha=0.001, learning_rate=constant, solver=lbfgs
# [CV]  warm_start=False, alpha=0.001, learning_rate=constant, solver=lbfgs, total=   0.7s
# [CV] warm_start=True, alpha=0.001, learning_rate=constant, solver=adam
# [CV]  warm_start=True, alpha=0.001, learning_rate=constant, solver=adam, total=   0.1s
# [CV] warm_start=True, alpha=0.001, learning_rate=constant, solver=adam
# [CV]  warm_start=True, alpha=0.001, learning_rate=constant, solver=adam, total=   0.1s
# [CV] warm_start=True, alpha=0.001, learning_rate=constant, solver=adam
# [CV]  warm_start=True, alpha=0.001, learning_rate=constant, solver=adam, total=   0.1s
# [CV] warm_start=False, alpha=0.001, learning_rate=constant, solver=adam
# [CV]  warm_start=False, alpha=0.001, learning_rate=constant, solver=adam, total=   0.1s
# [CV] warm_start=False, alpha=0.001, learning_rate=constant, solver=adam
# [CV]  warm_start=False, alpha=0.001, learning_rate=constant, solver=adam, total=   0.2s
# [CV] warm_start=False, alpha=0.001, learning_rate=constant, solver=adam
# [CV]  warm_start=False, alpha=0.001, learning_rate=constant, solver=adam, total=   0.1s
# [CV] warm_start=True, alpha=0.01, learning_rate=adaptive, solver=lbfgs
# [CV]  warm_start=True, alpha=0.01, learning_rate=adaptive, solver=lbfgs, total=   0.8s
# [CV] warm_start=True, alpha=0.01, learning_rate=adaptive, solver=lbfgs
# [CV]  warm_start=True, alpha=0.01, learning_rate=adaptive, solver=lbfgs, total=   0.7s
# [CV] warm_start=True, alpha=0.01, learning_rate=adaptive, solver=lbfgs
# [CV]  warm_start=True, alpha=0.01, learning_rate=adaptive, solver=lbfgs, total=   0.5s
# [CV] warm_start=False, alpha=0.01, learning_rate=adaptive, solver=lbfgs
# [CV]  warm_start=False, alpha=0.01, learning_rate=adaptive, solver=lbfgs, total=   0.8s
# [CV] warm_start=False, alpha=0.01, learning_rate=adaptive, solver=lbfgs
# [CV]  warm_start=False, alpha=0.01, learning_rate=adaptive, solver=lbfgs, total=   0.7s
# [CV] warm_start=False, alpha=0.01, learning_rate=adaptive, solver=lbfgs
# [CV]  warm_start=False, alpha=0.01, learning_rate=adaptive, solver=lbfgs, total=   0.5s
# [CV] warm_start=True, alpha=0.01, learning_rate=adaptive, solver=adam
# [CV]  warm_start=True, alpha=0.01, learning_rate=adaptive, solver=adam, total=   0.1s
# [CV] warm_start=True, alpha=0.01, learning_rate=adaptive, solver=adam
# [CV]  warm_start=True, alpha=0.01, learning_rate=adaptive, solver=adam, total=   0.1s
# [CV] warm_start=True, alpha=0.01, learning_rate=adaptive, solver=adam
# [CV]  warm_start=True, alpha=0.01, learning_rate=adaptive, solver=adam, total=   0.1s
# [CV] warm_start=False, alpha=0.01, learning_rate=adaptive, solver=adam
# [CV]  warm_start=False, alpha=0.01, learning_rate=adaptive, solver=adam, total=   0.1s
# [CV] warm_start=False, alpha=0.01, learning_rate=adaptive, solver=adam
# [CV]  warm_start=False, alpha=0.01, learning_rate=adaptive, solver=adam, total=   0.2s
# [CV] warm_start=False, alpha=0.01, learning_rate=adaptive, solver=adam
# [CV]  warm_start=False, alpha=0.01, learning_rate=adaptive, solver=adam, total=   0.1s
# [CV] warm_start=True, alpha=0.01, learning_rate=constant, solver=lbfgs
# [CV]  warm_start=True, alpha=0.01, learning_rate=constant, solver=lbfgs, total=   0.8s
# [CV] warm_start=True, alpha=0.01, learning_rate=constant, solver=lbfgs
# [CV]  warm_start=True, alpha=0.01, learning_rate=constant, solver=lbfgs, total=   0.7s
# [CV] warm_start=True, alpha=0.01, learning_rate=constant, solver=lbfgs
# [CV]  warm_start=True, alpha=0.01, learning_rate=constant, solver=lbfgs, total=   0.5s
# [CV] warm_start=False, alpha=0.01, learning_rate=constant, solver=lbfgs
# [CV]  warm_start=False, alpha=0.01, learning_rate=constant, solver=lbfgs, total=   0.8s
# [CV] warm_start=False, alpha=0.01, learning_rate=constant, solver=lbfgs
# [CV]  warm_start=False, alpha=0.01, learning_rate=constant, solver=lbfgs, total=   0.7s
# [CV] warm_start=False, alpha=0.01, learning_rate=constant, solver=lbfgs
# [CV]  warm_start=False, alpha=0.01, learning_rate=constant, solver=lbfgs, total=   0.4s
# [CV] warm_start=True, alpha=0.01, learning_rate=constant, solver=adam
# [CV]  warm_start=True, alpha=0.01, learning_rate=constant, solver=adam, total=   0.1s
# [CV] warm_start=True, alpha=0.01, learning_rate=constant, solver=adam
# [CV]  warm_start=True, alpha=0.01, learning_rate=constant, solver=adam, total=   0.1s
# [CV] warm_start=True, alpha=0.01, learning_rate=constant, solver=adam
# [CV]  warm_start=True, alpha=0.01, learning_rate=constant, solver=adam, total=   0.1s
# [CV] warm_start=False, alpha=0.01, learning_rate=constant, solver=adam
# [CV]  warm_start=False, alpha=0.01, learning_rate=constant, solver=adam, total=   0.1s
# [CV] warm_start=False, alpha=0.01, learning_rate=constant, solver=adam
# [CV]  warm_start=False, alpha=0.01, learning_rate=constant, solver=adam, total=   0.1s
# [CV] warm_start=False, alpha=0.01, learning_rate=constant, solver=adam
# [CV]  warm_start=False, alpha=0.01, learning_rate=constant, solver=adam, total=   0.1s
# [CV] warm_start=True, alpha=0.1, learning_rate=adaptive, solver=lbfgs
# [CV]  warm_start=True, alpha=0.1, learning_rate=adaptive, solver=lbfgs, total=   0.4s
# [CV] warm_start=True, alpha=0.1, learning_rate=adaptive, solver=lbfgs
# [CV]  warm_start=True, alpha=0.1, learning_rate=adaptive, solver=lbfgs, total=   0.4s
# [CV] warm_start=True, alpha=0.1, learning_rate=adaptive, solver=lbfgs
# [CV]  warm_start=True, alpha=0.1, learning_rate=adaptive, solver=lbfgs, total=   1.3s
# [CV] warm_start=False, alpha=0.1, learning_rate=adaptive, solver=lbfgs
# [CV]  warm_start=False, alpha=0.1, learning_rate=adaptive, solver=lbfgs, total=   0.4s
# [CV] warm_start=False, alpha=0.1, learning_rate=adaptive, solver=lbfgs
# [CV]  warm_start=False, alpha=0.1, learning_rate=adaptive, solver=lbfgs, total=   0.4s
# [CV] warm_start=False, alpha=0.1, learning_rate=adaptive, solver=lbfgs
# [CV]  warm_start=False, alpha=0.1, learning_rate=adaptive, solver=lbfgs, total=   1.3s
# [CV] warm_start=True, alpha=0.1, learning_rate=adaptive, solver=adam .
# [CV]  warm_start=True, alpha=0.1, learning_rate=adaptive, solver=adam, total=   0.1s
# [CV] warm_start=True, alpha=0.1, learning_rate=adaptive, solver=adam .
# [CV]  warm_start=True, alpha=0.1, learning_rate=adaptive, solver=adam, total=   0.1s
# [CV] warm_start=True, alpha=0.1, learning_rate=adaptive, solver=adam .
# [CV]  warm_start=True, alpha=0.1, learning_rate=adaptive, solver=adam, total=   0.1s
# [CV] warm_start=False, alpha=0.1, learning_rate=adaptive, solver=adam
# [CV]  warm_start=False, alpha=0.1, learning_rate=adaptive, solver=adam, total=   0.1s
# [CV] warm_start=False, alpha=0.1, learning_rate=adaptive, solver=adam
# [CV]  warm_start=False, alpha=0.1, learning_rate=adaptive, solver=adam, total=   0.1s
# [CV] warm_start=False, alpha=0.1, learning_rate=adaptive, solver=adam
# [CV]  warm_start=False, alpha=0.1, learning_rate=adaptive, solver=adam, total=   0.1s
# [CV] warm_start=True, alpha=0.1, learning_rate=constant, solver=lbfgs
# [CV]  warm_start=True, alpha=0.1, learning_rate=constant, solver=lbfgs, total=   0.4s
# [CV] warm_start=True, alpha=0.1, learning_rate=constant, solver=lbfgs
# [CV]  warm_start=True, alpha=0.1, learning_rate=constant, solver=lbfgs, total=   0.4s
# [CV] warm_start=True, alpha=0.1, learning_rate=constant, solver=lbfgs
# [CV]  warm_start=True, alpha=0.1, learning_rate=constant, solver=lbfgs, total=   1.3s
# [CV] warm_start=False, alpha=0.1, learning_rate=constant, solver=lbfgs
# [CV]  warm_start=False, alpha=0.1, learning_rate=constant, solver=lbfgs, total=   0.4s
# [CV] warm_start=False, alpha=0.1, learning_rate=constant, solver=lbfgs
# [CV]  warm_start=False, alpha=0.1, learning_rate=constant, solver=lbfgs, total=   0.4s
# [CV] warm_start=False, alpha=0.1, learning_rate=constant, solver=lbfgs
# [CV]  warm_start=False, alpha=0.1, learning_rate=constant, solver=lbfgs, total=   1.3s
# [CV] warm_start=True, alpha=0.1, learning_rate=constant, solver=adam .
# [CV]  warm_start=True, alpha=0.1, learning_rate=constant, solver=adam, total=   0.1s
# [CV] warm_start=True, alpha=0.1, learning_rate=constant, solver=adam .
# [CV]  warm_start=True, alpha=0.1, learning_rate=constant, solver=adam, total=   0.1s
# [CV] warm_start=True, alpha=0.1, learning_rate=constant, solver=adam .
# [CV]  warm_start=True, alpha=0.1, learning_rate=constant, solver=adam, total=   0.1s
# [CV] warm_start=False, alpha=0.1, learning_rate=constant, solver=adam
# [CV]  warm_start=False, alpha=0.1, learning_rate=constant, solver=adam, total=   0.1s
# [CV] warm_start=False, alpha=0.1, learning_rate=constant, solver=adam
# [CV]  warm_start=False, alpha=0.1, learning_rate=constant, solver=adam, total=   0.1s
# [CV] warm_start=False, alpha=0.1, learning_rate=constant, solver=adam
# [CV]  warm_start=False, alpha=0.1, learning_rate=constant, solver=adam, total=   0.1s
# [Parallel(n_jobs=1)]: Done 144 out of 144 | elapsed:  1.2min finished
# Optimised NN accuracy: 86.0%

# %%
print cv.best_params_
# Out:
# {'min_samples_split': 12, 'n_estimators': 10}

# %% [markdown]
# ### Varying the NN size with new best params

# %%
from sklearn.model_selection import GridSearchCV

rangespace = []
for l1 in range(1,20):
    for l2 in range(1,15):
        for l3 in range(1,10):
            rangespace.append((l1,l2,l3))
            

parameters = {'hidden_layer_sizes':rangespace}
nn = MLPClassifier(random_state=11,max_iter = 10000,warm_start=True,solver='adam',learning_rate='adaptive',alpha=0.01)

cv = GridSearchCV(nn, parameters,verbose = 2)
cv.fit(X_train_scaled,y_train)
y_predict = cv.predict(X_test_scaled)

print 'Optimised NN accuracy: ' + str(round(accuracy_score(y_test,y_predict),3) *100) + '%'
# Out:
# Fitting 3 folds for each of 2394 candidates, totalling 7182 fits
# [CV] hidden_layer_sizes=(1, 1, 1) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 1, 1), total=   0.2s
# [CV] hidden_layer_sizes=(1, 1, 1) ....................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s remaining:    0.0s
# [CV] ..................... hidden_layer_sizes=(1, 1, 1), total=   0.2s
# [CV] hidden_layer_sizes=(1, 1, 1) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 1, 1), total=   0.2s
# [CV] hidden_layer_sizes=(1, 1, 2) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 1, 2), total=   0.0s
# [CV] hidden_layer_sizes=(1, 1, 2) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 1, 2), total=   0.0s
# [CV] hidden_layer_sizes=(1, 1, 2) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 1, 2), total=   0.0s
# [CV] hidden_layer_sizes=(1, 1, 3) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 1, 3), total=   0.0s
# [CV] hidden_layer_sizes=(1, 1, 3) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 1, 3), total=   0.0s
# [CV] hidden_layer_sizes=(1, 1, 3) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 1, 3), total=   0.0s
# [CV] hidden_layer_sizes=(1, 1, 4) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 1, 4), total=   0.0s
# [CV] hidden_layer_sizes=(1, 1, 4) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 1, 4), total=   0.0s
# [CV] hidden_layer_sizes=(1, 1, 4) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 1, 4), total=   0.0s
# [CV] hidden_layer_sizes=(1, 1, 5) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 1, 5), total=   0.0s
# [CV] hidden_layer_sizes=(1, 1, 5) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 1, 5), total=   0.0s
# [CV] hidden_layer_sizes=(1, 1, 5) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 1, 5), total=   0.0s
# [CV] hidden_layer_sizes=(1, 1, 6) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 1, 6), total=   0.0s
# [CV] hidden_layer_sizes=(1, 1, 6) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 1, 6), total=   0.0s
# [CV] hidden_layer_sizes=(1, 1, 6) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 1, 6), total=   0.0s
# [CV] hidden_layer_sizes=(1, 1, 7) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 1, 7), total=   0.0s
# [CV] hidden_layer_sizes=(1, 1, 7) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 1, 7), total=   0.0s
# [CV] hidden_layer_sizes=(1, 1, 7) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 1, 7), total=   0.0s
# [CV] hidden_layer_sizes=(1, 1, 8) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 1, 8), total=   0.0s
# [CV] hidden_layer_sizes=(1, 1, 8) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 1, 8), total=   0.0s
# [CV] hidden_layer_sizes=(1, 1, 8) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 1, 8), total=   0.0s
# [CV] hidden_layer_sizes=(1, 1, 9) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 1, 9), total=   0.3s
# [CV] hidden_layer_sizes=(1, 1, 9) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 1, 9), total=   0.0s
# [CV] hidden_layer_sizes=(1, 1, 9) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 1, 9), total=   0.1s
# [CV] hidden_layer_sizes=(1, 2, 1) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 2, 1), total=   0.0s
# [CV] hidden_layer_sizes=(1, 2, 1) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 2, 1), total=   0.0s
# [CV] hidden_layer_sizes=(1, 2, 1) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 2, 1), total=   0.0s
# [CV] hidden_layer_sizes=(1, 2, 2) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 2, 2), total=   0.1s
# [CV] hidden_layer_sizes=(1, 2, 2) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 2, 2), total=   0.3s
# [CV] hidden_layer_sizes=(1, 2, 2) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 2, 2), total=   0.1s
# [CV] hidden_layer_sizes=(1, 2, 3) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 2, 3), total=   0.0s
# [CV] hidden_layer_sizes=(1, 2, 3) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 2, 3), total=   0.0s
# [CV] hidden_layer_sizes=(1, 2, 3) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 2, 3), total=   0.0s
# [CV] hidden_layer_sizes=(1, 2, 4) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 2, 4), total=   0.0s
# [CV] hidden_layer_sizes=(1, 2, 4) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 2, 4), total=   0.0s
# [CV] hidden_layer_sizes=(1, 2, 4) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 2, 4), total=   0.0s
# [CV] hidden_layer_sizes=(1, 2, 5) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 2, 5), total=   0.1s
# [CV] hidden_layer_sizes=(1, 2, 5) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 2, 5), total=   0.0s
# [CV] hidden_layer_sizes=(1, 2, 5) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 2, 5), total=   0.1s
# [CV] hidden_layer_sizes=(1, 2, 6) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 2, 6), total=   0.4s
# [CV] hidden_layer_sizes=(1, 2, 6) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 2, 6), total=   0.3s
# [CV] hidden_layer_sizes=(1, 2, 6) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 2, 6), total=   0.2s
# [CV] hidden_layer_sizes=(1, 2, 7) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 2, 7), total=   0.2s
# [CV] hidden_layer_sizes=(1, 2, 7) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 2, 7), total=   0.2s
# [CV] hidden_layer_sizes=(1, 2, 7) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 2, 7), total=   0.1s
# [CV] hidden_layer_sizes=(1, 2, 8) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 2, 8), total=   0.0s
# [CV] hidden_layer_sizes=(1, 2, 8) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 2, 8), total=   0.0s
# [CV] hidden_layer_sizes=(1, 2, 8) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 2, 8), total=   0.0s
# [CV] hidden_layer_sizes=(1, 2, 9) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 2, 9), total=   0.0s
# [CV] hidden_layer_sizes=(1, 2, 9) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 2, 9), total=   0.0s
# [CV] hidden_layer_sizes=(1, 2, 9) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 2, 9), total=   0.1s
# [CV] hidden_layer_sizes=(1, 3, 1) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 3, 1), total=   0.0s
# [CV] hidden_layer_sizes=(1, 3, 1) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 3, 1), total=   0.0s
# [CV] hidden_layer_sizes=(1, 3, 1) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 3, 1), total=   0.0s
# [CV] hidden_layer_sizes=(1, 3, 2) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 3, 2), total=   0.0s
# [CV] hidden_layer_sizes=(1, 3, 2) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 3, 2), total=   0.0s
# [CV] hidden_layer_sizes=(1, 3, 2) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 3, 2), total=   0.0s
# [CV] hidden_layer_sizes=(1, 3, 3) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 3, 3), total=   0.1s
# [CV] hidden_layer_sizes=(1, 3, 3) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 3, 3), total=   0.1s
# [CV] hidden_layer_sizes=(1, 3, 3) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 3, 3), total=   0.1s
# [CV] hidden_layer_sizes=(1, 3, 4) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 3, 4), total=   0.1s
# [CV] hidden_layer_sizes=(1, 3, 4) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 3, 4), total=   0.2s
# [CV] hidden_layer_sizes=(1, 3, 4) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 3, 4), total=   0.0s
# [CV] hidden_layer_sizes=(1, 3, 5) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 3, 5), total=   0.0s
# [CV] hidden_layer_sizes=(1, 3, 5) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 3, 5), total=   0.0s
# [CV] hidden_layer_sizes=(1, 3, 5) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 3, 5), total=   0.0s
# [CV] hidden_layer_sizes=(1, 3, 6) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 3, 6), total=   0.0s
# [CV] hidden_layer_sizes=(1, 3, 6) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 3, 6), total=   0.0s
# [CV] hidden_layer_sizes=(1, 3, 6) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 3, 6), total=   0.0s
# [CV] hidden_layer_sizes=(1, 3, 7) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 3, 7), total=   0.0s
# [CV] hidden_layer_sizes=(1, 3, 7) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 3, 7), total=   0.0s
# [CV] hidden_layer_sizes=(1, 3, 7) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 3, 7), total=   0.0s
# [CV] hidden_layer_sizes=(1, 3, 8) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 3, 8), total=   0.0s
# [CV] hidden_layer_sizes=(1, 3, 8) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 3, 8), total=   0.0s
# [CV] hidden_layer_sizes=(1, 3, 8) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 3, 8), total=   0.0s
# [CV] hidden_layer_sizes=(1, 3, 9) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 3, 9), total=   0.0s
# [CV] hidden_layer_sizes=(1, 3, 9) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 3, 9), total=   0.0s
# [CV] hidden_layer_sizes=(1, 3, 9) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 3, 9), total=   0.0s
# [CV] hidden_layer_sizes=(1, 4, 1) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 4, 1), total=   0.5s
# [CV] hidden_layer_sizes=(1, 4, 1) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 4, 1), total=   0.4s
# [CV] hidden_layer_sizes=(1, 4, 1) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 4, 1), total=   0.5s
# [CV] hidden_layer_sizes=(1, 4, 2) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 4, 2), total=   0.1s
# [CV] hidden_layer_sizes=(1, 4, 2) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 4, 2), total=   0.1s
# [CV] hidden_layer_sizes=(1, 4, 2) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 4, 2), total=   0.2s
# [CV] hidden_layer_sizes=(1, 4, 3) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 4, 3), total=   0.2s
# [CV] hidden_layer_sizes=(1, 4, 3) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 4, 3), total=   0.0s
# [CV] hidden_layer_sizes=(1, 4, 3) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 4, 3), total=   0.0s
# [CV] hidden_layer_sizes=(1, 4, 4) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 4, 4), total=   0.2s
# [CV] hidden_layer_sizes=(1, 4, 4) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 4, 4), total=   0.0s
# [CV] hidden_layer_sizes=(1, 4, 4) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 4, 4), total=   0.0s
# [CV] hidden_layer_sizes=(1, 4, 5) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 4, 5), total=   0.0s
# [CV] hidden_layer_sizes=(1, 4, 5) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 4, 5), total=   0.0s
# [CV] hidden_layer_sizes=(1, 4, 5) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 4, 5), total=   0.2s
# [CV] hidden_layer_sizes=(1, 4, 6) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 4, 6), total=   0.0s
# [CV] hidden_layer_sizes=(1, 4, 6) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 4, 6), total=   0.0s
# [CV] hidden_layer_sizes=(1, 4, 6) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 4, 6), total=   0.0s
# [CV] hidden_layer_sizes=(1, 4, 7) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 4, 7), total=   0.0s
# [CV] hidden_layer_sizes=(1, 4, 7) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 4, 7), total=   0.0s
# [CV] hidden_layer_sizes=(1, 4, 7) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 4, 7), total=   0.0s
# [CV] hidden_layer_sizes=(1, 4, 8) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 4, 8), total=   0.0s
# [CV] hidden_layer_sizes=(1, 4, 8) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 4, 8), total=   0.0s
# [CV] hidden_layer_sizes=(1, 4, 8) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 4, 8), total=   0.0s
# [CV] hidden_layer_sizes=(1, 4, 9) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 4, 9), total=   0.0s
# [CV] hidden_layer_sizes=(1, 4, 9) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 4, 9), total=   0.0s
# [CV] hidden_layer_sizes=(1, 4, 9) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 4, 9), total=   0.0s
# [CV] hidden_layer_sizes=(1, 5, 1) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 5, 1), total=   0.2s
# [CV] hidden_layer_sizes=(1, 5, 1) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 5, 1), total=   0.2s
# [CV] hidden_layer_sizes=(1, 5, 1) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 5, 1), total=   0.2s
# [CV] hidden_layer_sizes=(1, 5, 2) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 5, 2), total=   0.3s
# [CV] hidden_layer_sizes=(1, 5, 2) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 5, 2), total=   0.2s
# [CV] hidden_layer_sizes=(1, 5, 2) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 5, 2), total=   0.3s
# [CV] hidden_layer_sizes=(1, 5, 3) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 5, 3), total=   0.0s
# [CV] hidden_layer_sizes=(1, 5, 3) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 5, 3), total=   0.0s
# [CV] hidden_layer_sizes=(1, 5, 3) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 5, 3), total=   0.0s
# [CV] hidden_layer_sizes=(1, 5, 4) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 5, 4), total=   0.0s
# [CV] hidden_layer_sizes=(1, 5, 4) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 5, 4), total=   0.0s
# [CV] hidden_layer_sizes=(1, 5, 4) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 5, 4), total=   0.0s
# [CV] hidden_layer_sizes=(1, 5, 5) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 5, 5), total=   0.3s
# [CV] hidden_layer_sizes=(1, 5, 5) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 5, 5), total=   0.0s
# [CV] hidden_layer_sizes=(1, 5, 5) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 5, 5), total=   0.1s
# [CV] hidden_layer_sizes=(1, 5, 6) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 5, 6), total=   0.0s
# [CV] hidden_layer_sizes=(1, 5, 6) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 5, 6), total=   0.0s
# [CV] hidden_layer_sizes=(1, 5, 6) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 5, 6), total=   0.0s
# [CV] hidden_layer_sizes=(1, 5, 7) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 5, 7), total=   0.1s
# [CV] hidden_layer_sizes=(1, 5, 7) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 5, 7), total=   0.1s
# [CV] hidden_layer_sizes=(1, 5, 7) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 5, 7), total=   0.1s
# [CV] hidden_layer_sizes=(1, 5, 8) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 5, 8), total=   0.0s
# [CV] hidden_layer_sizes=(1, 5, 8) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 5, 8), total=   0.0s
# [CV] hidden_layer_sizes=(1, 5, 8) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 5, 8), total=   0.3s
# [CV] hidden_layer_sizes=(1, 5, 9) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 5, 9), total=   0.0s
# [CV] hidden_layer_sizes=(1, 5, 9) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 5, 9), total=   0.0s
# [CV] hidden_layer_sizes=(1, 5, 9) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 5, 9), total=   0.0s
# [CV] hidden_layer_sizes=(1, 6, 1) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 6, 1), total=   0.2s
# [CV] hidden_layer_sizes=(1, 6, 1) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 6, 1), total=   0.1s
# [CV] hidden_layer_sizes=(1, 6, 1) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 6, 1), total=   0.1s
# [CV] hidden_layer_sizes=(1, 6, 2) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 6, 2), total=   0.1s
# [CV] hidden_layer_sizes=(1, 6, 2) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 6, 2), total=   0.1s
# [CV] hidden_layer_sizes=(1, 6, 2) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 6, 2), total=   0.1s
# [CV] hidden_layer_sizes=(1, 6, 3) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 6, 3), total=   0.0s
# [CV] hidden_layer_sizes=(1, 6, 3) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 6, 3), total=   0.3s
# [CV] hidden_layer_sizes=(1, 6, 3) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 6, 3), total=   0.0s
# [CV] hidden_layer_sizes=(1, 6, 4) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 6, 4), total=   0.0s
# [CV] hidden_layer_sizes=(1, 6, 4) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 6, 4), total=   0.0s
# [CV] hidden_layer_sizes=(1, 6, 4) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 6, 4), total=   0.0s
# [CV] hidden_layer_sizes=(1, 6, 5) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 6, 5), total=   0.0s
# [CV] hidden_layer_sizes=(1, 6, 5) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 6, 5), total=   0.0s
# [CV] hidden_layer_sizes=(1, 6, 5) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 6, 5), total=   0.0s
# [CV] hidden_layer_sizes=(1, 6, 6) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 6, 6), total=   0.1s
# [CV] hidden_layer_sizes=(1, 6, 6) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 6, 6), total=   0.1s
# [CV] hidden_layer_sizes=(1, 6, 6) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 6, 6), total=   0.1s
# [CV] hidden_layer_sizes=(1, 6, 7) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 6, 7), total=   0.0s
# [CV] hidden_layer_sizes=(1, 6, 7) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 6, 7), total=   0.0s
# [CV] hidden_layer_sizes=(1, 6, 7) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 6, 7), total=   0.0s
# [CV] hidden_layer_sizes=(1, 6, 8) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 6, 8), total=   0.0s
# [CV] hidden_layer_sizes=(1, 6, 8) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 6, 8), total=   0.0s
# [CV] hidden_layer_sizes=(1, 6, 8) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 6, 8), total=   0.0s
# [CV] hidden_layer_sizes=(1, 6, 9) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 6, 9), total=   0.2s
# [CV] hidden_layer_sizes=(1, 6, 9) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 6, 9), total=   0.0s
# [CV] hidden_layer_sizes=(1, 6, 9) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 6, 9), total=   0.0s
# [CV] hidden_layer_sizes=(1, 7, 1) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 7, 1), total=   0.0s
# [CV] hidden_layer_sizes=(1, 7, 1) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 7, 1), total=   0.0s
# [CV] hidden_layer_sizes=(1, 7, 1) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 7, 1), total=   0.0s
# [CV] hidden_layer_sizes=(1, 7, 2) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 7, 2), total=   0.0s
# [CV] hidden_layer_sizes=(1, 7, 2) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 7, 2), total=   0.0s
# [CV] hidden_layer_sizes=(1, 7, 2) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 7, 2), total=   0.0s
# [CV] hidden_layer_sizes=(1, 7, 3) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 7, 3), total=   0.3s
# [CV] hidden_layer_sizes=(1, 7, 3) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 7, 3), total=   0.3s
# [CV] hidden_layer_sizes=(1, 7, 3) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 7, 3), total=   0.4s
# [CV] hidden_layer_sizes=(1, 7, 4) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 7, 4), total=   0.0s
# [CV] hidden_layer_sizes=(1, 7, 4) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 7, 4), total=   0.0s
# [CV] hidden_layer_sizes=(1, 7, 4) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 7, 4), total=   0.0s
# [CV] hidden_layer_sizes=(1, 7, 5) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 7, 5), total=   0.1s
# [CV] hidden_layer_sizes=(1, 7, 5) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 7, 5), total=   0.1s
# [CV] hidden_layer_sizes=(1, 7, 5) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 7, 5), total=   0.1s
# [CV] hidden_layer_sizes=(1, 7, 6) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 7, 6), total=   0.0s
# [CV] hidden_layer_sizes=(1, 7, 6) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 7, 6), total=   0.0s
# [CV] hidden_layer_sizes=(1, 7, 6) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 7, 6), total=   0.0s
# [CV] hidden_layer_sizes=(1, 7, 7) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 7, 7), total=   0.0s
# [CV] hidden_layer_sizes=(1, 7, 7) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 7, 7), total=   0.0s
# [CV] hidden_layer_sizes=(1, 7, 7) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 7, 7), total=   0.0s
# [CV] hidden_layer_sizes=(1, 7, 8) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 7, 8), total=   0.0s
# [CV] hidden_layer_sizes=(1, 7, 8) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 7, 8), total=   0.0s
# [CV] hidden_layer_sizes=(1, 7, 8) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 7, 8), total=   0.0s
# [CV] hidden_layer_sizes=(1, 7, 9) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 7, 9), total=   0.2s
# [CV] hidden_layer_sizes=(1, 7, 9) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 7, 9), total=   0.0s
# [CV] hidden_layer_sizes=(1, 7, 9) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 7, 9), total=   0.1s
# [CV] hidden_layer_sizes=(1, 8, 1) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 8, 1), total=   0.2s
# [CV] hidden_layer_sizes=(1, 8, 1) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 8, 1), total=   0.2s
# [CV] hidden_layer_sizes=(1, 8, 1) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 8, 1), total=   0.1s
# [CV] hidden_layer_sizes=(1, 8, 2) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 8, 2), total=   0.0s
# [CV] hidden_layer_sizes=(1, 8, 2) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 8, 2), total=   0.0s
# [CV] hidden_layer_sizes=(1, 8, 2) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 8, 2), total=   0.0s
# [CV] hidden_layer_sizes=(1, 8, 3) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 8, 3), total=   0.2s
# [CV] hidden_layer_sizes=(1, 8, 3) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 8, 3), total=   0.0s
# [CV] hidden_layer_sizes=(1, 8, 3) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 8, 3), total=   0.0s
# [CV] hidden_layer_sizes=(1, 8, 4) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 8, 4), total=   0.0s
# [CV] hidden_layer_sizes=(1, 8, 4) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 8, 4), total=   0.0s
# [CV] hidden_layer_sizes=(1, 8, 4) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 8, 4), total=   0.0s
# [CV] hidden_layer_sizes=(1, 8, 5) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 8, 5), total=   0.0s
# [CV] hidden_layer_sizes=(1, 8, 5) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 8, 5), total=   0.0s
# [CV] hidden_layer_sizes=(1, 8, 5) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 8, 5), total=   0.0s
# [CV] hidden_layer_sizes=(1, 8, 6) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 8, 6), total=   0.0s
# [CV] hidden_layer_sizes=(1, 8, 6) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 8, 6), total=   0.0s
# [CV] hidden_layer_sizes=(1, 8, 6) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 8, 6), total=   0.0s
# [CV] hidden_layer_sizes=(1, 8, 7) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 8, 7), total=   0.1s
# [CV] hidden_layer_sizes=(1, 8, 7) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 8, 7), total=   0.1s
# [CV] hidden_layer_sizes=(1, 8, 7) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 8, 7), total=   0.1s
# [CV] hidden_layer_sizes=(1, 8, 8) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 8, 8), total=   0.0s
# [CV] hidden_layer_sizes=(1, 8, 8) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 8, 8), total=   0.0s
# [CV] hidden_layer_sizes=(1, 8, 8) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 8, 8), total=   0.0s
# [CV] hidden_layer_sizes=(1, 8, 9) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 8, 9), total=   0.0s
# [CV] hidden_layer_sizes=(1, 8, 9) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 8, 9), total=   0.0s
# [CV] hidden_layer_sizes=(1, 8, 9) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 8, 9), total=   0.0s
# [CV] hidden_layer_sizes=(1, 9, 1) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 9, 1), total=   0.8s
# [CV] hidden_layer_sizes=(1, 9, 1) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 9, 1), total=   0.7s
# [CV] hidden_layer_sizes=(1, 9, 1) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 9, 1), total=   0.7s
# [CV] hidden_layer_sizes=(1, 9, 2) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 9, 2), total=   0.2s
# [CV] hidden_layer_sizes=(1, 9, 2) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 9, 2), total=   0.2s
# [CV] hidden_layer_sizes=(1, 9, 2) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 9, 2), total=   0.0s
# [CV] hidden_layer_sizes=(1, 9, 3) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 9, 3), total=   0.0s
# [CV] hidden_layer_sizes=(1, 9, 3) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 9, 3), total=   0.0s
# [CV] hidden_layer_sizes=(1, 9, 3) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 9, 3), total=   0.0s
# [CV] hidden_layer_sizes=(1, 9, 4) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 9, 4), total=   0.4s
# [CV] hidden_layer_sizes=(1, 9, 4) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 9, 4), total=   0.4s
# [CV] hidden_layer_sizes=(1, 9, 4) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 9, 4), total=   0.5s
# [CV] hidden_layer_sizes=(1, 9, 5) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 9, 5), total=   0.0s
# [CV] hidden_layer_sizes=(1, 9, 5) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 9, 5), total=   0.0s
# [CV] hidden_layer_sizes=(1, 9, 5) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 9, 5), total=   0.0s
# [CV] hidden_layer_sizes=(1, 9, 6) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 9, 6), total=   0.0s
# [CV] hidden_layer_sizes=(1, 9, 6) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 9, 6), total=   0.0s
# [CV] hidden_layer_sizes=(1, 9, 6) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 9, 6), total=   0.2s
# [CV] hidden_layer_sizes=(1, 9, 7) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 9, 7), total=   0.0s
# [CV] hidden_layer_sizes=(1, 9, 7) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 9, 7), total=   0.0s
# [CV] hidden_layer_sizes=(1, 9, 7) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 9, 7), total=   0.0s
# [CV] hidden_layer_sizes=(1, 9, 8) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 9, 8), total=   0.0s
# [CV] hidden_layer_sizes=(1, 9, 8) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 9, 8), total=   0.0s
# [CV] hidden_layer_sizes=(1, 9, 8) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 9, 8), total=   0.0s
# [CV] hidden_layer_sizes=(1, 9, 9) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 9, 9), total=   0.0s
# [CV] hidden_layer_sizes=(1, 9, 9) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 9, 9), total=   0.0s
# [CV] hidden_layer_sizes=(1, 9, 9) ....................................
# [CV] ..................... hidden_layer_sizes=(1, 9, 9), total=   0.0s
# [CV] hidden_layer_sizes=(1, 10, 1) ...................................
# [CV] .................... hidden_layer_sizes=(1, 10, 1), total=   0.0s
# [CV] hidden_layer_sizes=(1, 10, 1) ...................................
# [CV] .................... hidden_layer_sizes=(1, 10, 1), total=   0.1s
# [CV] hidden_layer_sizes=(1, 10, 1) ...................................
# [CV] .................... hidden_layer_sizes=(1, 10, 1), total=   0.1s
# [CV] hidden_layer_sizes=(1, 10, 2) ...................................
# [CV] .................... hidden_layer_sizes=(1, 10, 2), total=   0.0s
# [CV] hidden_layer_sizes=(1, 10, 2) ...................................
# [CV] .................... hidden_layer_sizes=(1, 10, 2), total=   0.0s
# [CV] hidden_layer_sizes=(1, 10, 2) ...................................
# [CV] .................... hidden_layer_sizes=(1, 10, 2), total=   0.0s
# [CV] hidden_layer_sizes=(1, 10, 3) ...................................
# [CV] .................... hidden_layer_sizes=(1, 10, 3), total=   0.0s
# [CV] hidden_layer_sizes=(1, 10, 3) ...................................
# [CV] .................... hidden_layer_sizes=(1, 10, 3), total=   0.0s
# [CV] hidden_layer_sizes=(1, 10, 3) ...................................
# [CV] .................... hidden_layer_sizes=(1, 10, 3), total=   0.0s
# [CV] hidden_layer_sizes=(1, 10, 4) ...................................
# [CV] .................... hidden_layer_sizes=(1, 10, 4), total=   0.0s
# [CV] hidden_layer_sizes=(1, 10, 4) ...................................
# [CV] .................... hidden_layer_sizes=(1, 10, 4), total=   0.0s
# [CV] hidden_layer_sizes=(1, 10, 4) ...................................
# [CV] .................... hidden_layer_sizes=(1, 10, 4), total=   0.0s
# [CV] hidden_layer_sizes=(1, 10, 5) ...................................
# [CV] .................... hidden_layer_sizes=(1, 10, 5), total=   0.1s
# [CV] hidden_layer_sizes=(1, 10, 5) ...................................
# [CV] .................... hidden_layer_sizes=(1, 10, 5), total=   0.1s
# [CV] hidden_layer_sizes=(1, 10, 5) ...................................
# [CV] .................... hidden_layer_sizes=(1, 10, 5), total=   0.2s
# [CV] hidden_layer_sizes=(1, 10, 6) ...................................
# [CV] .................... hidden_layer_sizes=(1, 10, 6), total=   0.0s
# [CV] hidden_layer_sizes=(1, 10, 6) ...................................
# [CV] .................... hidden_layer_sizes=(1, 10, 6), total=   0.0s
# [CV] hidden_layer_sizes=(1, 10, 6) ...................................
# [CV] .................... hidden_layer_sizes=(1, 10, 6), total=   0.0s
# [CV] hidden_layer_sizes=(1, 10, 7) ...................................
# [CV] .................... hidden_layer_sizes=(1, 10, 7), total=   0.0s
# [CV] hidden_layer_sizes=(1, 10, 7) ...................................
# [CV] .................... hidden_layer_sizes=(1, 10, 7), total=   0.0s
# [CV] hidden_layer_sizes=(1, 10, 7) ...................................
# [CV] .................... hidden_layer_sizes=(1, 10, 7), total=   0.0s
# [CV] hidden_layer_sizes=(1, 10, 8) ...................................
# [CV] .................... hidden_layer_sizes=(1, 10, 8), total=   0.0s
# [CV] hidden_layer_sizes=(1, 10, 8) ...................................
# [CV] .................... hidden_layer_sizes=(1, 10, 8), total=   0.0s
# [CV] hidden_layer_sizes=(1, 10, 8) ...................................
# [CV] .................... hidden_layer_sizes=(1, 10, 8), total=   0.0s
# [CV] hidden_layer_sizes=(1, 10, 9) ...................................
# [CV] .................... hidden_layer_sizes=(1, 10, 9), total=   0.0s
# [CV] hidden_layer_sizes=(1, 10, 9) ...................................
# [CV] .................... hidden_layer_sizes=(1, 10, 9), total=   0.0s
# [CV] hidden_layer_sizes=(1, 10, 9) ...................................
# [CV] .................... hidden_layer_sizes=(1, 10, 9), total=   0.0s
# [CV] hidden_layer_sizes=(1, 11, 1) ...................................
# [CV] .................... hidden_layer_sizes=(1, 11, 1), total=   0.2s
# [CV] hidden_layer_sizes=(1, 11, 1) ...................................
# [CV] .................... hidden_layer_sizes=(1, 11, 1), total=   0.2s
# [CV] hidden_layer_sizes=(1, 11, 1) ...................................
# [CV] .................... hidden_layer_sizes=(1, 11, 1), total=   0.2s
# [CV] hidden_layer_sizes=(1, 11, 2) ...................................
# [CV] .................... hidden_layer_sizes=(1, 11, 2), total=   0.0s
# [CV] hidden_layer_sizes=(1, 11, 2) ...................................
# [CV] .................... hidden_layer_sizes=(1, 11, 2), total=   0.0s
# [CV] hidden_layer_sizes=(1, 11, 2) ...................................
# [CV] .................... hidden_layer_sizes=(1, 11, 2), total=   0.0s
# [CV] hidden_layer_sizes=(1, 11, 3) ...................................
# [CV] .................... hidden_layer_sizes=(1, 11, 3), total=   0.1s
# [CV] hidden_layer_sizes=(1, 11, 3) ...................................
# [CV] .................... hidden_layer_sizes=(1, 11, 3), total=   0.2s
# [CV] hidden_layer_sizes=(1, 11, 3) ...................................
# [CV] .................... hidden_layer_sizes=(1, 11, 3), total=   0.6s
# [CV] hidden_layer_sizes=(1, 11, 4) ...................................
# [CV] .................... hidden_layer_sizes=(1, 11, 4), total=   0.1s
# [CV] hidden_layer_sizes=(1, 11, 4) ...................................
# [CV] .................... hidden_layer_sizes=(1, 11, 4), total=   0.1s
# [CV] hidden_layer_sizes=(1, 11, 4) ...................................
# [CV] .................... hidden_layer_sizes=(1, 11, 4), total=   0.1s
# [CV] hidden_layer_sizes=(1, 11, 5) ...................................
# [CV] .................... hidden_layer_sizes=(1, 11, 5), total=   0.0s
# [CV] hidden_layer_sizes=(1, 11, 5) ...................................
# [CV] .................... hidden_layer_sizes=(1, 11, 5), total=   0.0s
# [CV] hidden_layer_sizes=(1, 11, 5) ...................................
# [CV] .................... hidden_layer_sizes=(1, 11, 5), total=   0.0s
# [CV] hidden_layer_sizes=(1, 11, 6) ...................................
# [CV] .................... hidden_layer_sizes=(1, 11, 6), total=   0.0s
# [CV] hidden_layer_sizes=(1, 11, 6) ...................................
# [CV] .................... hidden_layer_sizes=(1, 11, 6), total=   0.0s
# [CV] hidden_layer_sizes=(1, 11, 6) ...................................
# [CV] .................... hidden_layer_sizes=(1, 11, 6), total=   0.0s
# [CV] hidden_layer_sizes=(1, 11, 7) ...................................
# [CV] .................... hidden_layer_sizes=(1, 11, 7), total=   0.0s
# [CV] hidden_layer_sizes=(1, 11, 7) ...................................
# [CV] .................... hidden_layer_sizes=(1, 11, 7), total=   0.0s
# [CV] hidden_layer_sizes=(1, 11, 7) ...................................
# [CV] .................... hidden_layer_sizes=(1, 11, 7), total=   0.0s
# [CV] hidden_layer_sizes=(1, 11, 8) ...................................
# [CV] .................... hidden_layer_sizes=(1, 11, 8), total=   0.0s
# [CV] hidden_layer_sizes=(1, 11, 8) ...................................
# [CV] .................... hidden_layer_sizes=(1, 11, 8), total=   0.0s
# [CV] hidden_layer_sizes=(1, 11, 8) ...................................
# [CV] .................... hidden_layer_sizes=(1, 11, 8), total=   0.0s
# [CV] hidden_layer_sizes=(1, 11, 9) ...................................
# [CV] .................... hidden_layer_sizes=(1, 11, 9), total=   0.0s
# [CV] hidden_layer_sizes=(1, 11, 9) ...................................
# [CV] .................... hidden_layer_sizes=(1, 11, 9), total=   0.0s
# [CV] hidden_layer_sizes=(1, 11, 9) ...................................
# [CV] .................... hidden_layer_sizes=(1, 11, 9), total=   0.0s
# [CV] hidden_layer_sizes=(1, 12, 1) ...................................
# [CV] .................... hidden_layer_sizes=(1, 12, 1), total=   0.0s
# [CV] hidden_layer_sizes=(1, 12, 1) ...................................
# [CV] .................... hidden_layer_sizes=(1, 12, 1), total=   0.0s
# [CV] hidden_layer_sizes=(1, 12, 1) ...................................
# [CV] .................... hidden_layer_sizes=(1, 12, 1), total=   0.0s
# [CV] hidden_layer_sizes=(1, 12, 2) ...................................
# [CV] .................... hidden_layer_sizes=(1, 12, 2), total=   0.2s
# [CV] hidden_layer_sizes=(1, 12, 2) ...................................
# [CV] .................... hidden_layer_sizes=(1, 12, 2), total=   0.1s
# [CV] hidden_layer_sizes=(1, 12, 2) ...................................
# [CV] .................... hidden_layer_sizes=(1, 12, 2), total=   0.0s
# [CV] hidden_layer_sizes=(1, 12, 3) ...................................
# [CV] .................... hidden_layer_sizes=(1, 12, 3), total=   0.0s
# [CV] hidden_layer_sizes=(1, 12, 3) ...................................
# [CV] .................... hidden_layer_sizes=(1, 12, 3), total=   0.0s
# [CV] hidden_layer_sizes=(1, 12, 3) ...................................
# [CV] .................... hidden_layer_sizes=(1, 12, 3), total=   0.2s
# [CV] hidden_layer_sizes=(1, 12, 4) ...................................
# [CV] .................... hidden_layer_sizes=(1, 12, 4), total=   0.0s
# [CV] hidden_layer_sizes=(1, 12, 4) ...................................
# [CV] .................... hidden_layer_sizes=(1, 12, 4), total=   0.0s
# [CV] hidden_layer_sizes=(1, 12, 4) ...................................
# [CV] .................... hidden_layer_sizes=(1, 12, 4), total=   0.0s
# [CV] hidden_layer_sizes=(1, 12, 5) ...................................
# [CV] .................... hidden_layer_sizes=(1, 12, 5), total=   0.2s
# [CV] hidden_layer_sizes=(1, 12, 5) ...................................
# [CV] .................... hidden_layer_sizes=(1, 12, 5), total=   0.0s
# [CV] hidden_layer_sizes=(1, 12, 5) ...................................
# [CV] .................... hidden_layer_sizes=(1, 12, 5), total=   0.1s
# [CV] hidden_layer_sizes=(1, 12, 6) ...................................
# [CV] .................... hidden_layer_sizes=(1, 12, 6), total=   0.3s
# [CV] hidden_layer_sizes=(1, 12, 6) ...................................
# [CV] .................... hidden_layer_sizes=(1, 12, 6), total=   0.3s
# [CV] hidden_layer_sizes=(1, 12, 6) ...................................
# [CV] .................... hidden_layer_sizes=(1, 12, 6), total=   0.3s
# [CV] hidden_layer_sizes=(1, 12, 7) ...................................
# [CV] .................... hidden_layer_sizes=(1, 12, 7), total=   0.0s
# [CV] hidden_layer_sizes=(1, 12, 7) ...................................
# [CV] .................... hidden_layer_sizes=(1, 12, 7), total=   0.0s
# [CV] hidden_layer_sizes=(1, 12, 7) ...................................
# [CV] .................... hidden_layer_sizes=(1, 12, 7), total=   0.0s
# [CV] hidden_layer_sizes=(1, 12, 8) ...................................
# [CV] .................... hidden_layer_sizes=(1, 12, 8), total=   0.0s
# [CV] hidden_layer_sizes=(1, 12, 8) ...................................
# [CV] .................... hidden_layer_sizes=(1, 12, 8), total=   0.0s
# [CV] hidden_layer_sizes=(1, 12, 8) ...................................
# [CV] .................... hidden_layer_sizes=(1, 12, 8), total=   0.0s
# [CV] hidden_layer_sizes=(1, 12, 9) ...................................
# [CV] .................... hidden_layer_sizes=(1, 12, 9), total=   0.0s
# [CV] hidden_layer_sizes=(1, 12, 9) ...................................
# [CV] .................... hidden_layer_sizes=(1, 12, 9), total=   0.0s
# [CV] hidden_layer_sizes=(1, 12, 9) ...................................
# [CV] .................... hidden_layer_sizes=(1, 12, 9), total=   0.0s
# [CV] hidden_layer_sizes=(1, 13, 1) ...................................
# [CV] .................... hidden_layer_sizes=(1, 13, 1), total=   0.7s
# [CV] hidden_layer_sizes=(1, 13, 1) ...................................
# [CV] .................... hidden_layer_sizes=(1, 13, 1), total=   0.7s
# [CV] hidden_layer_sizes=(1, 13, 1) ...................................
# [CV] .................... hidden_layer_sizes=(1, 13, 1), total=   0.5s
# [CV] hidden_layer_sizes=(1, 13, 2) ...................................
# [CV] .................... hidden_layer_sizes=(1, 13, 2), total=   0.0s
# [CV] hidden_layer_sizes=(1, 13, 2) ...................................
# [CV] .................... hidden_layer_sizes=(1, 13, 2), total=   0.0s
# [CV] hidden_layer_sizes=(1, 13, 2) ...................................
# [CV] .................... hidden_layer_sizes=(1, 13, 2), total=   0.0s
# [CV] hidden_layer_sizes=(1, 13, 3) ...................................
# [CV] .................... hidden_layer_sizes=(1, 13, 3), total=   0.6s
# [CV] hidden_layer_sizes=(1, 13, 3) ...................................
# [CV] .................... hidden_layer_sizes=(1, 13, 3), total=   0.1s
# [CV] hidden_layer_sizes=(1, 13, 3) ...................................
# [CV] .................... hidden_layer_sizes=(1, 13, 3), total=   0.2s
# [CV] hidden_layer_sizes=(1, 13, 4) ...................................
# [CV] .................... hidden_layer_sizes=(1, 13, 4), total=   0.0s
# [CV] hidden_layer_sizes=(1, 13, 4) ...................................
# [CV] .................... hidden_layer_sizes=(1, 13, 4), total=   0.0s
# [CV] hidden_layer_sizes=(1, 13, 4) ...................................
# [CV] .................... hidden_layer_sizes=(1, 13, 4), total=   0.2s
# [CV] hidden_layer_sizes=(1, 13, 5) ...................................
# [CV] .................... hidden_layer_sizes=(1, 13, 5), total=   0.0s
# ...
# [CV] ................... hidden_layer_sizes=(19, 10, 8), total=   0.1s
# [CV] hidden_layer_sizes=(19, 10, 9) ..................................
# [CV] ................... hidden_layer_sizes=(19, 10, 9), total=   0.2s
# [CV] hidden_layer_sizes=(19, 10, 9) ..................................
# [CV] ................... hidden_layer_sizes=(19, 10, 9), total=   0.1s
# [CV] hidden_layer_sizes=(19, 10, 9) ..................................
# [CV] ................... hidden_layer_sizes=(19, 10, 9), total=   0.2s
# [CV] hidden_layer_sizes=(19, 11, 1) ..................................
# [CV] ................... hidden_layer_sizes=(19, 11, 1), total=   0.5s
# [CV] hidden_layer_sizes=(19, 11, 1) ..................................
# [CV] ................... hidden_layer_sizes=(19, 11, 1), total=   0.5s
# [CV] hidden_layer_sizes=(19, 11, 1) ..................................
# [CV] ................... hidden_layer_sizes=(19, 11, 1), total=   0.6s
# [CV] hidden_layer_sizes=(19, 11, 2) ..................................
# [CV] ................... hidden_layer_sizes=(19, 11, 2), total=   0.2s
# [CV] hidden_layer_sizes=(19, 11, 2) ..................................
# [CV] ................... hidden_layer_sizes=(19, 11, 2), total=   0.2s
# [CV] hidden_layer_sizes=(19, 11, 2) ..................................
# [CV] ................... hidden_layer_sizes=(19, 11, 2), total=   0.2s
# [CV] hidden_layer_sizes=(19, 11, 3) ..................................
# [CV] ................... hidden_layer_sizes=(19, 11, 3), total=   0.2s
# [CV] hidden_layer_sizes=(19, 11, 3) ..................................
# [CV] ................... hidden_layer_sizes=(19, 11, 3), total=   0.1s
# [CV] hidden_layer_sizes=(19, 11, 3) ..................................
# [CV] ................... hidden_layer_sizes=(19, 11, 3), total=   0.2s
# [CV] hidden_layer_sizes=(19, 11, 4) ..................................
# [CV] ................... hidden_layer_sizes=(19, 11, 4), total=   0.1s
# [CV] hidden_layer_sizes=(19, 11, 4) ..................................
# [CV] ................... hidden_layer_sizes=(19, 11, 4), total=   0.2s
# [CV] hidden_layer_sizes=(19, 11, 4) ..................................
# [CV] ................... hidden_layer_sizes=(19, 11, 4), total=   0.2s
# [CV] hidden_layer_sizes=(19, 11, 5) ..................................
# [CV] ................... hidden_layer_sizes=(19, 11, 5), total=   0.1s
# [CV] hidden_layer_sizes=(19, 11, 5) ..................................
# [CV] ................... hidden_layer_sizes=(19, 11, 5), total=   0.1s
# [CV] hidden_layer_sizes=(19, 11, 5) ..................................
# [CV] ................... hidden_layer_sizes=(19, 11, 5), total=   0.3s
# [CV] hidden_layer_sizes=(19, 11, 6) ..................................
# [CV] ................... hidden_layer_sizes=(19, 11, 6), total=   0.1s
# [CV] hidden_layer_sizes=(19, 11, 6) ..................................
# [CV] ................... hidden_layer_sizes=(19, 11, 6), total=   0.1s
# [CV] hidden_layer_sizes=(19, 11, 6) ..................................
# [CV] ................... hidden_layer_sizes=(19, 11, 6), total=   0.2s
# [CV] hidden_layer_sizes=(19, 11, 7) ..................................
# [CV] ................... hidden_layer_sizes=(19, 11, 7), total=   0.1s
# [CV] hidden_layer_sizes=(19, 11, 7) ..................................
# [CV] ................... hidden_layer_sizes=(19, 11, 7), total=   0.1s
# [CV] hidden_layer_sizes=(19, 11, 7) ..................................
# [CV] ................... hidden_layer_sizes=(19, 11, 7), total=   0.2s
# [CV] hidden_layer_sizes=(19, 11, 8) ..................................
# [CV] ................... hidden_layer_sizes=(19, 11, 8), total=   0.1s
# [CV] hidden_layer_sizes=(19, 11, 8) ..................................
# [CV] ................... hidden_layer_sizes=(19, 11, 8), total=   0.2s
# [CV] hidden_layer_sizes=(19, 11, 8) ..................................
# [CV] ................... hidden_layer_sizes=(19, 11, 8), total=   0.1s
# [CV] hidden_layer_sizes=(19, 11, 9) ..................................
# [CV] ................... hidden_layer_sizes=(19, 11, 9), total=   0.1s
# [CV] hidden_layer_sizes=(19, 11, 9) ..................................
# [CV] ................... hidden_layer_sizes=(19, 11, 9), total=   0.1s
# [CV] hidden_layer_sizes=(19, 11, 9) ..................................
# [CV] ................... hidden_layer_sizes=(19, 11, 9), total=   0.2s
# [CV] hidden_layer_sizes=(19, 12, 1) ..................................
# [CV] ................... hidden_layer_sizes=(19, 12, 1), total=   0.4s
# [CV] hidden_layer_sizes=(19, 12, 1) ..................................
# [CV] ................... hidden_layer_sizes=(19, 12, 1), total=   0.3s
# [CV] hidden_layer_sizes=(19, 12, 1) ..................................
# [CV] ................... hidden_layer_sizes=(19, 12, 1), total=   0.3s
# [CV] hidden_layer_sizes=(19, 12, 2) ..................................
# [CV] ................... hidden_layer_sizes=(19, 12, 2), total=   0.2s
# [CV] hidden_layer_sizes=(19, 12, 2) ..................................
# [CV] ................... hidden_layer_sizes=(19, 12, 2), total=   0.2s
# [CV] hidden_layer_sizes=(19, 12, 2) ..................................
# [CV] ................... hidden_layer_sizes=(19, 12, 2), total=   0.3s
# [CV] hidden_layer_sizes=(19, 12, 3) ..................................
# [CV] ................... hidden_layer_sizes=(19, 12, 3), total=   0.2s
# [CV] hidden_layer_sizes=(19, 12, 3) ..................................
# [CV] ................... hidden_layer_sizes=(19, 12, 3), total=   0.1s
# [CV] hidden_layer_sizes=(19, 12, 3) ..................................
# [CV] ................... hidden_layer_sizes=(19, 12, 3), total=   0.2s
# [CV] hidden_layer_sizes=(19, 12, 4) ..................................
# [CV] ................... hidden_layer_sizes=(19, 12, 4), total=   0.2s
# [CV] hidden_layer_sizes=(19, 12, 4) ..................................
# [CV] ................... hidden_layer_sizes=(19, 12, 4), total=   0.1s
# [CV] hidden_layer_sizes=(19, 12, 4) ..................................
# [CV] ................... hidden_layer_sizes=(19, 12, 4), total=   0.2s
# [CV] hidden_layer_sizes=(19, 12, 5) ..................................
# [CV] ................... hidden_layer_sizes=(19, 12, 5), total=   0.7s
# [CV] hidden_layer_sizes=(19, 12, 5) ..................................
# [CV] ................... hidden_layer_sizes=(19, 12, 5), total=   0.8s
# [CV] hidden_layer_sizes=(19, 12, 5) ..................................
# [CV] ................... hidden_layer_sizes=(19, 12, 5), total=   0.8s
# [CV] hidden_layer_sizes=(19, 12, 6) ..................................
# [CV] ................... hidden_layer_sizes=(19, 12, 6), total=   0.2s
# [CV] hidden_layer_sizes=(19, 12, 6) ..................................
# [CV] ................... hidden_layer_sizes=(19, 12, 6), total=   0.2s
# [CV] hidden_layer_sizes=(19, 12, 6) ..................................
# [CV] ................... hidden_layer_sizes=(19, 12, 6), total=   0.3s
# [CV] hidden_layer_sizes=(19, 12, 7) ..................................
# [CV] ................... hidden_layer_sizes=(19, 12, 7), total=   0.1s
# [CV] hidden_layer_sizes=(19, 12, 7) ..................................
# [CV] ................... hidden_layer_sizes=(19, 12, 7), total=   0.0s
# [CV] hidden_layer_sizes=(19, 12, 7) ..................................
# [CV] ................... hidden_layer_sizes=(19, 12, 7), total=   0.2s
# [CV] hidden_layer_sizes=(19, 12, 8) ..................................
# [CV] ................... hidden_layer_sizes=(19, 12, 8), total=   0.1s
# [CV] hidden_layer_sizes=(19, 12, 8) ..................................
# [CV] ................... hidden_layer_sizes=(19, 12, 8), total=   0.0s
# [CV] hidden_layer_sizes=(19, 12, 8) ..................................
# [CV] ................... hidden_layer_sizes=(19, 12, 8), total=   0.1s
# [CV] hidden_layer_sizes=(19, 12, 9) ..................................
# [CV] ................... hidden_layer_sizes=(19, 12, 9), total=   0.0s
# [CV] hidden_layer_sizes=(19, 12, 9) ..................................
# [CV] ................... hidden_layer_sizes=(19, 12, 9), total=   0.1s
# [CV] hidden_layer_sizes=(19, 12, 9) ..................................
# [CV] ................... hidden_layer_sizes=(19, 12, 9), total=   0.2s
# [CV] hidden_layer_sizes=(19, 13, 1) ..................................
# [CV] ................... hidden_layer_sizes=(19, 13, 1), total=   0.4s
# [CV] hidden_layer_sizes=(19, 13, 1) ..................................
# [CV] ................... hidden_layer_sizes=(19, 13, 1), total=   0.3s
# [CV] hidden_layer_sizes=(19, 13, 1) ..................................
# [CV] ................... hidden_layer_sizes=(19, 13, 1), total=   0.5s
# [CV] hidden_layer_sizes=(19, 13, 2) ..................................
# [CV] ................... hidden_layer_sizes=(19, 13, 2), total=   0.3s
# [CV] hidden_layer_sizes=(19, 13, 2) ..................................
# [CV] ................... hidden_layer_sizes=(19, 13, 2), total=   0.4s
# [CV] hidden_layer_sizes=(19, 13, 2) ..................................
# [CV] ................... hidden_layer_sizes=(19, 13, 2), total=   0.5s
# [CV] hidden_layer_sizes=(19, 13, 3) ..................................
# [CV] ................... hidden_layer_sizes=(19, 13, 3), total=   0.2s
# [CV] hidden_layer_sizes=(19, 13, 3) ..................................
# [CV] ................... hidden_layer_sizes=(19, 13, 3), total=   0.1s
# [CV] hidden_layer_sizes=(19, 13, 3) ..................................
# [CV] ................... hidden_layer_sizes=(19, 13, 3), total=   0.1s
# [CV] hidden_layer_sizes=(19, 13, 4) ..................................
# [CV] ................... hidden_layer_sizes=(19, 13, 4), total=   0.3s
# [CV] hidden_layer_sizes=(19, 13, 4) ..................................
# [CV] ................... hidden_layer_sizes=(19, 13, 4), total=   0.2s
# [CV] hidden_layer_sizes=(19, 13, 4) ..................................
# [CV] ................... hidden_layer_sizes=(19, 13, 4), total=   0.2s
# [CV] hidden_layer_sizes=(19, 13, 5) ..................................
# [CV] ................... hidden_layer_sizes=(19, 13, 5), total=   0.2s
# [CV] hidden_layer_sizes=(19, 13, 5) ..................................
# [CV] ................... hidden_layer_sizes=(19, 13, 5), total=   0.4s
# [CV] hidden_layer_sizes=(19, 13, 5) ..................................
# [CV] ................... hidden_layer_sizes=(19, 13, 5), total=   0.5s
# [CV] hidden_layer_sizes=(19, 13, 6) ..................................
# [CV] ................... hidden_layer_sizes=(19, 13, 6), total=   0.2s
# [CV] hidden_layer_sizes=(19, 13, 6) ..................................
# [CV] ................... hidden_layer_sizes=(19, 13, 6), total=   0.1s
# [CV] hidden_layer_sizes=(19, 13, 6) ..................................
# [CV] ................... hidden_layer_sizes=(19, 13, 6), total=   0.4s
# [CV] hidden_layer_sizes=(19, 13, 7) ..................................
# [CV] ................... hidden_layer_sizes=(19, 13, 7), total=   0.3s
# [CV] hidden_layer_sizes=(19, 13, 7) ..................................
# [CV] ................... hidden_layer_sizes=(19, 13, 7), total=   0.3s
# [CV] hidden_layer_sizes=(19, 13, 7) ..................................
# [CV] ................... hidden_layer_sizes=(19, 13, 7), total=   0.1s
# [CV] hidden_layer_sizes=(19, 13, 8) ..................................
# [CV] ................... hidden_layer_sizes=(19, 13, 8), total=   0.3s
# [CV] hidden_layer_sizes=(19, 13, 8) ..................................
# [CV] ................... hidden_layer_sizes=(19, 13, 8), total=   0.2s
# [CV] hidden_layer_sizes=(19, 13, 8) ..................................
# [CV] ................... hidden_layer_sizes=(19, 13, 8), total=   0.1s
# [CV] hidden_layer_sizes=(19, 13, 9) ..................................
# [CV] ................... hidden_layer_sizes=(19, 13, 9), total=   0.2s
# [CV] hidden_layer_sizes=(19, 13, 9) ..................................
# [CV] ................... hidden_layer_sizes=(19, 13, 9), total=   0.2s
# [CV] hidden_layer_sizes=(19, 13, 9) ..................................
# [CV] ................... hidden_layer_sizes=(19, 13, 9), total=   0.1s
# [CV] hidden_layer_sizes=(19, 14, 1) ..................................
# [CV] ................... hidden_layer_sizes=(19, 14, 1), total=   0.7s
# [CV] hidden_layer_sizes=(19, 14, 1) ..................................
# [CV] ................... hidden_layer_sizes=(19, 14, 1), total=   0.9s
# [CV] hidden_layer_sizes=(19, 14, 1) ..................................
# [CV] ................... hidden_layer_sizes=(19, 14, 1), total=   1.0s
# [CV] hidden_layer_sizes=(19, 14, 2) ..................................
# [CV] ................... hidden_layer_sizes=(19, 14, 2), total=   0.4s
# [CV] hidden_layer_sizes=(19, 14, 2) ..................................
# [CV] ................... hidden_layer_sizes=(19, 14, 2), total=   0.4s
# [CV] hidden_layer_sizes=(19, 14, 2) ..................................
# [CV] ................... hidden_layer_sizes=(19, 14, 2), total=   0.3s
# [CV] hidden_layer_sizes=(19, 14, 3) ..................................
# [CV] ................... hidden_layer_sizes=(19, 14, 3), total=   0.7s
# [CV] hidden_layer_sizes=(19, 14, 3) ..................................
# [CV] ................... hidden_layer_sizes=(19, 14, 3), total=   0.7s
# [CV] hidden_layer_sizes=(19, 14, 3) ..................................
# [CV] ................... hidden_layer_sizes=(19, 14, 3), total=   0.8s
# [CV] hidden_layer_sizes=(19, 14, 4) ..................................
# [CV] ................... hidden_layer_sizes=(19, 14, 4), total=   0.1s
# [CV] hidden_layer_sizes=(19, 14, 4) ..................................
# [CV] ................... hidden_layer_sizes=(19, 14, 4), total=   0.7s
# [CV] hidden_layer_sizes=(19, 14, 4) ..................................
# [CV] ................... hidden_layer_sizes=(19, 14, 4), total=   0.7s
# [CV] hidden_layer_sizes=(19, 14, 5) ..................................
# [CV] ................... hidden_layer_sizes=(19, 14, 5), total=   0.2s
# [CV] hidden_layer_sizes=(19, 14, 5) ..................................
# [CV] ................... hidden_layer_sizes=(19, 14, 5), total=   0.1s
# [CV] hidden_layer_sizes=(19, 14, 5) ..................................
# [CV] ................... hidden_layer_sizes=(19, 14, 5), total=   0.2s
# [CV] hidden_layer_sizes=(19, 14, 6) ..................................
# [CV] ................... hidden_layer_sizes=(19, 14, 6), total=   0.2s
# [CV] hidden_layer_sizes=(19, 14, 6) ..................................
# [CV] ................... hidden_layer_sizes=(19, 14, 6), total=   0.1s
# [CV] hidden_layer_sizes=(19, 14, 6) ..................................
# [CV] ................... hidden_layer_sizes=(19, 14, 6), total=   0.2s
# [CV] hidden_layer_sizes=(19, 14, 7) ..................................
# [CV] ................... hidden_layer_sizes=(19, 14, 7), total=   0.1s
# [CV] hidden_layer_sizes=(19, 14, 7) ..................................
# [CV] ................... hidden_layer_sizes=(19, 14, 7), total=   0.1s
# [CV] hidden_layer_sizes=(19, 14, 7) ..................................
# [CV] ................... hidden_layer_sizes=(19, 14, 7), total=   0.1s
# [CV] hidden_layer_sizes=(19, 14, 8) ..................................
# [CV] ................... hidden_layer_sizes=(19, 14, 8), total=   0.1s
# [CV] hidden_layer_sizes=(19, 14, 8) ..................................
# [CV] ................... hidden_layer_sizes=(19, 14, 8), total=   0.1s
# [CV] hidden_layer_sizes=(19, 14, 8) ..................................
# [CV] ................... hidden_layer_sizes=(19, 14, 8), total=   0.3s
# [CV] hidden_layer_sizes=(19, 14, 9) ..................................
# [CV] ................... hidden_layer_sizes=(19, 14, 9), total=   0.1s
# [CV] hidden_layer_sizes=(19, 14, 9) ..................................
# [CV] ................... hidden_layer_sizes=(19, 14, 9), total=   0.2s
# [CV] hidden_layer_sizes=(19, 14, 9) ..................................
# [CV] ................... hidden_layer_sizes=(19, 14, 9), total=   0.2s
# [Parallel(n_jobs=1)]: Done 7182 out of 7182 | elapsed: 91.8min finished
# Optimised NN accuracy: 87.7%

# %% [markdown]
# ## Using best classifier on test set

# %% [markdown]
# ### Import and treat test data

# %%
df_test = pd.read_csv('test.csv')
X_test_final = df_test[["Pclass","Sex","Fare","Age","SibSp"]]
X_test_final = pd.get_dummies(X_test_final)
imp = Imputer(missing_values='NaN', strategy='mean',axis=0)
imp.fit(X_test_final)
X_test_final = imp.transform(X_test_final)

# %% [markdown]
# ### Treat full training data

# %%
X_train_final = imp.transform(X_imputed)
scaler = StandardScaler()
scaler.fit(X_train_final)
X_train_final = scaler.transform(X_train_final)
X_test_final = scaler.transform(X_test_final)

# %% [markdown]
# ### Construct, train and predict

# %%
nn = MLPClassifier(random_state=11,max_iter = 10000,warm_start=True,solver='adam',learning_rate='adaptive',alpha=0.01,hidden_layer_sizes=(5, 10,5))
nn.fit(X_train_final, y) 
y_predict_final = nn.predict(X_test_final)

# %%
df_entry =  pd.Series.to_frame(df_test["PassengerId"])
df_entry["Survived"] = pd.Series(y_predict_final)
df_entry.to_csv("prediction_1_nn.csv",sep=',')
print df_entry.columns
# Out:
# Index([u'PassengerId', u'Survived'], dtype='object')

# %% [markdown]
# ## Second attempt: using RF classisifier

# %%
df_test = pd.read_csv('test.csv')
X_test_final = df_test[["Pclass","Sex","Fare","Age","SibSp"]]
X_test_final = pd.get_dummies(X_test_final)
imp = Imputer(missing_values='NaN', strategy='mean',axis=0)
imp.fit(X_test_final)
X_test_final = imp.transform(X_test_final)
X_train_final = imp.transform(X_imputed)

rf = RandomForestClassifier(bootstrap=True,warm_start=True,n_estimators=20,min_samples_split=2)
rf.fit(X_train_final, y) 
y_predict_final = rf.predict(X_test_final)

df_entry =  pd.Series.to_frame(df_test["PassengerId"])
df_entry["Survived"] = pd.Series(y_predict_final)
df_entry.to_csv("prediction_3_rf.csv",sep=',')
print df_entry.columns
# Out:
# Index([u'PassengerId', u'Survived'], dtype='object')
